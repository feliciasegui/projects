# %% [markdown]
# # Assignment #4: Extracting syntactic groups using machine-learning techniques
# Author: Pierre Nugues

# %% [markdown]
# In this assignment, you will create a system to extract syntactic groups from a text. You will apply it to the CoNLL 2000 dataset. In addition, you will try to link a few extracted named entities to real things using wikipedia.

# %% [markdown]
# ## Objectives

# %% [markdown]
# The objectives of this assignment are to:
# * Write a program to detect partial syntactic structures
# * Extract named entities and link them to real things using Wikipedia
# * Understand the principles of supervised machine learning techniques applied to language processing
# * Use a popular machine learning toolkit: scikit-learn
# * Write a short report of 2 to 3 pages on the assignment

# %% [markdown]
# ## Choosing a training and a test sets

# %% [markdown]
# * As annotated data and annotation scheme, you will use the data available from [CoNLL 2000](https://www.clips.uantwerpen.be/conll2000/chunking/).
# * Download both the training and test sets and decompress them.
# * Local copies are also available here: [train.txt](https://fileadmin.cs.lth.se/cs/Education/EDAN20/corpus/conll2000/train.txt) and [test.txt](https://fileadmin.cs.lth.se/cs/Education/EDAN20/corpus/conll2000/test.txt)
# * Read the description of the CoNLL 2000 task

# %% [markdown]
# ## Loading the corpus

# %% [markdown]
# ### The datasets

# %% [markdown]
# You may need to adjust the paths to load the datasets.

# %%
train_file = 'train.txt'
test_file = 'test.txt'

# %% [markdown]
# #### Reading the files

# %% [markdown]
# Read the functions below to load the datasets. They store the corpus in a list of sentences. Each sentence is a list of rows, where each row is a dictionary.

# %%
def read_sentences(file):
    """
    Creates a list of sentences from the corpus
    Each sentence is a string
    :param file:
    :return:
    """
    f = open(file).read().strip()
    sentences = f.split('\n\n')
    return sentences

# %%
def split_rows(sentences, column_names):
    """
    Creates a list of sentence where each sentence is a list of lines
    Each line is a dictionary of columns
    :param sentences:
    :param column_names:
    :return:
    """
    new_sentences = []
    for sentence in sentences:
        rows = sentence.split('\n')
        sentence = [dict(zip(column_names, row.split())) for row in rows]
        new_sentences.append(sentence)
    return new_sentences

# %% [markdown]
# ### Loading dictionaries

# %% [markdown]
# The CoNLL 2000 files have three columns

# %%
column_names = ['form', 'pos', 'chunk']

# %% [markdown]
# We load the corpus

# %%
train_sentences = read_sentences(train_file)
train_corpus = split_rows(train_sentences, column_names)
train_corpus[:2]
# Out:
# [[{'form': 'Confidence', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'in', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'pound', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'is', 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'widely', 'pos': 'RB', 'chunk': 'I-VP'},
#   {'form': 'expected', 'pos': 'VBN', 'chunk': 'I-VP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'I-VP'},
#   {'form': 'take', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'another', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'sharp', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'dive', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'if', 'pos': 'IN', 'chunk': 'B-SBAR'},
#   {'form': 'trade', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'figures', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'September', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'due', 'pos': 'JJ', 'chunk': 'B-ADJP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'release', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'tomorrow', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'fail', 'pos': 'VB', 'chunk': 'B-VP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'I-VP'},
#   {'form': 'show', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'a', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'substantial', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'improvement', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'from', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'July', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'and', 'pos': 'CC', 'chunk': 'I-NP'},
#   {'form': 'August', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': "'s", 'pos': 'POS', 'chunk': 'B-NP'},
#   {'form': 'near-record', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'deficits', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'Chancellor', 'pos': 'NNP', 'chunk': 'O'},
#   {'form': 'of', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'Exchequer', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'Nigel', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'Lawson', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': "'s", 'pos': 'POS', 'chunk': 'B-NP'},
#   {'form': 'restated', 'pos': 'VBN', 'chunk': 'I-NP'},
#   {'form': 'commitment', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'B-PP'},
#   {'form': 'a', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'firm', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'monetary', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'policy', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'has', 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'helped', 'pos': 'VBN', 'chunk': 'I-VP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'I-VP'},
#   {'form': 'prevent', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'a', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'freefall', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'in', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'sterling', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'over', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'past', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'week', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}]]

# %% [markdown]
# ## Baseline chunker

# %% [markdown]
# Most statistical algorithms for language processing start with a so-called baseline. The baseline performance corresponds to the application of a minimal technique that is used to assess the difficulty of a task and for comparison with further programs.
#
# You will implement the baseline proposed by the organizers of the
#         <a href="https://www.clips.uantwerpen.be/conll2000/chunking/">CoNLL 2000 shared task</a>, Sect. <i>Results</i>.
# 1. Read it;
# 2. In the report you will tell what do you think of it.

# %% [markdown]
# ### Auxiliary functions

# %% [markdown]
# A function to count the parts of speech

# %%
def count_pos(corpus):
    """
    Computes the part-of-speech distribution
    in a CoNLL 2000 file
    :param corpus:
    :return:
    """
    pos_cnt = {}
    for sentence in corpus:
        for row in sentence:
            if row['pos'] in pos_cnt:
                pos_cnt[row['pos']] += 1
            else:
                pos_cnt[row['pos']] = 1
    return pos_cnt

# %% [markdown]
# We first collect all the parts of speech and we count them.

# %%
pos_cnt = count_pos(train_corpus)
pos_cnt
# Out:
# {'NN': 30147,
#  'IN': 22764,
#  'DT': 18335,
#  'VBZ': 4648,
#  'RB': 6607,
#  'VBN': 4763,
#  'TO': 5081,
#  'VB': 6017,
#  'JJ': 13085,
#  'NNS': 13619,
#  'NNP': 19884,
#  ',': 10770,
#  'CC': 5372,
#  'POS': 1769,
#  '.': 8827,
#  'VBP': 2868,
#  'VBG': 3272,
#  'PRP$': 1881,
#  'CD': 8315,
#  '``': 1531,
#  "''": 1493,
#  'VBD': 6745,
#  'EX': 206,
#  'MD': 2167,
#  '#': 36,
#  '(': 274,
#  '$': 1750,
#  ')': 281,
#  'NNPS': 420,
#  'PRP': 3820,
#  'JJS': 374,
#  'WP': 529,
#  'RBR': 321,
#  'JJR': 853,
#  'WDT': 955,
#  'WRB': 478,
#  'RBS': 191,
#  'PDT': 55,
#  'RP': 83,
#  ':': 1047,
#  'FW': 38,
#  'WP$': 35,
#  'SYM': 6,
#  'UH': 15}

# %% [markdown]
# ### Chunk distribution

# %% [markdown]
# You will compute the chunk distribution for each part of speech. You will use the training file to derive the distribution and you will store the results in a dictionary. Below, you have an excerpt of the expected results:
# ```
# {'JJR':
# {'I-ADVP': 17, 'I-ADJP': 45, 'I-NP': 204, 'B-ADVP': 63,
# 'B-PP': 2, 'B-ADJP': 111, 'B-NP': 382, 'B-VP': 2,
# 'I-VP': 11, 'O': 16},
# 'CC':
# {'B-ADVP': 3, 'O': 3676, 'I-VP': 104, 'B-CONJP': 6,
# 'I-ADVP': 30, 'I-UCP': 2, 'I-PP': 24, 'I-ADJP': 26,
# 'I-NP': 1409, 'B-ADJP': 2, 'B-NP': 18, 'B-PP': 70,
# 'I-PRT': 1, 'B-VP': 1},
# 'NN':
# {'B-LST': 2, 'I-INTJ': 2, 'B-ADVP': 38, 'O': 37,
# 'I-ADVP': 11, 'B-INTJ': 1, 'I-UCP': 2, 'B-UCP': 2,
# 'I-VP': 77, 'B-PRT': 2, 'I-ADJP': 41, 'I-NP': 24456,
# 'B-ADJP': 44, 'B-NP': 5160, 'B-PP': 15, 'B-VP': 257},
# ...
# ```

# %%
def chunk_dis(corpus):
    chunk_dist = {}
    
    for sentence in corpus:
        for row in sentence:
            if row['pos'] in chunk_dist:
                if row['chunk'] in chunk_dist[row['pos']]:
                    chunk_dist[row['pos']][row['chunk']] +=1
                else:
                    chunk_dist[row['pos']][row['chunk']] = 1
            else:
                chunk_dist[row['pos']] = {row['chunk'] : 1}
    
    
    return chunk_dist

# %%
chunk_dist = chunk_dis(train_corpus)
chunk_dist
# Out:
# {'NN': {'B-NP': 5160,
#   'I-NP': 24456,
#   'B-VP': 257,
#   'B-ADJP': 44,
#   'B-ADVP': 38,
#   'O': 37,
#   'B-PP': 15,
#   'I-ADVP': 11,
#   'I-ADJP': 41,
#   'I-VP': 77,
#   'B-INTJ': 1,
#   'B-LST': 2,
#   'B-UCP': 2,
#   'I-UCP': 2,
#   'B-PRT': 2,
#   'I-INTJ': 2},
#  'IN': {'B-PP': 18683,
#   'B-SBAR': 2112,
#   'B-ADVP': 396,
#   'I-NP': 216,
#   'I-SBAR': 68,
#   'I-PP': 250,
#   'B-PRT': 404,
#   'B-NP': 418,
#   'B-ADJP': 31,
#   'O': 88,
#   'I-VP': 20,
#   'I-CONJP': 35,
#   'I-ADJP': 12,
#   'B-CONJP': 4,
#   'I-ADVP': 24,
#   'B-VP': 3},
#  'DT': {'B-NP': 17807,
#   'O': 135,
#   'I-NP': 299,
#   'B-ADVP': 24,
#   'I-VP': 7,
#   'B-VP': 4,
#   'B-INTJ': 6,
#   'B-SBAR': 20,
#   'I-SBAR': 2,
#   'I-ADVP': 15,
#   'B-ADJP': 8,
#   'I-PP': 1,
#   'B-LST': 1,
#   'B-PP': 5,
#   'I-INTJ': 1},
#  'VBZ': {'B-VP': 4469,
#   'I-NP': 76,
#   'I-INTJ': 2,
#   'I-VP': 31,
#   'O': 20,
#   'B-NP': 49,
#   'B-ADVP': 1},
#  'RB': {'I-VP': 1258,
#   'B-ADVP': 2890,
#   'I-ADVP': 250,
#   'I-NP': 307,
#   'B-ADJP': 399,
#   'B-NP': 621,
#   'B-SBAR': 68,
#   'B-PP': 72,
#   'I-PP': 9,
#   'O': 344,
#   'B-VP': 178,
#   'I-ADJP': 47,
#   'B-CONJP': 46,
#   'I-CONJP': 38,
#   'B-PRT': 74,
#   'B-INTJ': 5,
#   'I-PRT': 1},
#  'VBN': {'I-VP': 2806,
#   'I-NP': 453,
#   'B-VP': 1094,
#   'B-PP': 78,
#   'I-ADJP': 44,
#   'B-NP': 187,
#   'B-ADJP': 92,
#   'B-ADVP': 1,
#   'O': 7,
#   'I-ADVP': 1},
#  'TO': {'I-VP': 1110,
#   'B-PP': 2013,
#   'B-VP': 1822,
#   'I-NP': 90,
#   'I-ADVP': 5,
#   'B-ADVP': 2,
#   'I-ADJP': 1,
#   'O': 33,
#   'I-PP': 5},
#  'VB': {'I-VP': 5388,
#   'B-VP': 434,
#   'B-NP': 124,
#   'B-INTJ': 2,
#   'I-NP': 39,
#   'B-ADJP': 4,
#   'I-ADJP': 3,
#   'I-ADVP': 3,
#   'B-PP': 6,
#   'O': 8,
#   'B-PRT': 2,
#   'B-ADVP': 4},
#  'JJ': {'I-NP': 6771,
#   'B-ADJP': 1210,
#   'B-NP': 4304,
#   'I-ADJP': 383,
#   'B-ADVP': 159,
#   'B-VP': 47,
#   'B-PP': 92,
#   'O': 37,
#   'I-ADVP': 27,
#   'I-VP': 49,
#   'B-INTJ': 2,
#   'I-PP': 1,
#   'B-PRT': 2,
#   'B-SBAR': 1},
#  'NNS': {'I-NP': 9996,
#   'B-NP': 3464,
#   'B-VP': 142,
#   'I-ADVP': 2,
#   'O': 7,
#   'I-VP': 4,
#   'B-ADVP': 1,
#   'I-ADJP': 2,
#   'I-UCP': 1},
#  'NNP': {'B-NP': 8314,
#   'I-NP': 11470,
#   'O': 57,
#   'B-VP': 18,
#   'B-ADVP': 9,
#   'I-ADVP': 1,
#   'I-VP': 2,
#   'B-PRT': 1,
#   'B-ADJP': 8,
#   'B-INTJ': 2,
#   'I-ADJP': 2},
#  ',': {'O': 10195,
#   'I-NP': 512,
#   'B-PP': 15,
#   'B-NP': 24,
#   'B-ADVP': 1,
#   'I-VP': 9,
#   'I-ADJP': 5,
#   'B-ADJP': 2,
#   'I-INTJ': 2,
#   'B-VP': 4,
#   'I-UCP': 1},
#  'CC': {'I-NP': 1409,
#   'O': 3676,
#   'B-ADVP': 3,
#   'I-ADVP': 30,
#   'B-ADJP': 2,
#   'B-PP': 70,
#   'I-VP': 104,
#   'I-ADJP': 26,
#   'B-NP': 18,
#   'I-PP': 24,
#   'B-CONJP': 6,
#   'I-PRT': 1,
#   'B-VP': 1,
#   'I-UCP': 2},
#  'POS': {'B-NP': 1750, 'B-VP': 5, 'I-NP': 12, 'O': 2},
#  '.': {'O': 8813, 'I-NP': 14},
#  'VBP': {'B-VP': 2749,
#   'I-NP': 60,
#   'I-VP': 24,
#   'B-NP': 10,
#   'B-ADVP': 3,
#   'B-INTJ': 4,
#   'O': 11,
#   'B-ADJP': 6,
#   'B-PP': 1},
#  'VBG': {'B-NP': 188,
#   'B-VP': 1570,
#   'I-VP': 955,
#   'I-NP': 336,
#   'B-PP': 207,
#   'I-ADJP': 2,
#   'B-ADJP': 9,
#   'I-ADVP': 1,
#   'I-PP': 1,
#   'O': 3},
#  'PRP$': {'B-NP': 1858, 'I-NP': 19, 'O': 4},
#  'CD': {'B-NP': 3153,
#   'I-NP': 5050,
#   'O': 64,
#   'B-LST': 7,
#   'B-ADVP': 6,
#   'I-ADVP': 3,
#   'B-ADJP': 24,
#   'I-ADJP': 6,
#   'B-VP': 2},
#  '``': {'O': 1301,
#   'I-NP': 156,
#   'B-NP': 40,
#   'I-VP': 16,
#   'B-VP': 7,
#   'B-ADJP': 5,
#   'I-ADJP': 2,
#   'B-PP': 2,
#   'B-INTJ': 1,
#   'B-ADVP': 1},
#  "''": {'O': 1397, 'I-NP': 83, 'I-VP': 2, 'B-NP': 10, 'B-PP': 1},
#  'VBD': {'B-VP': 6527,
#   'B-NP': 25,
#   'I-VP': 113,
#   'I-ADJP': 5,
#   'I-NP': 49,
#   'O': 17,
#   'B-PP': 4,
#   'B-ADJP': 5},
#  'EX': {'B-NP': 189, 'B-ADVP': 15, 'I-ADVP': 2},
#  'MD': {'B-VP': 2121, 'O': 37, 'I-VP': 4, 'I-NP': 5},
#  '#': {'O': 4, 'I-NP': 10, 'B-ADJP': 3, 'B-NP': 19},
#  '(': {'O': 263, 'I-NP': 7, 'I-VP': 1, 'B-SBAR': 1, 'B-NP': 2},
#  '$': {'B-ADJP': 19, 'B-NP': 1309, 'I-NP': 419, 'O': 3},
#  ')': {'O': 275, 'I-NP': 6},
#  'NNPS': {'I-NP': 343, 'B-NP': 77},
#  'PRP': {'B-NP': 3804, 'I-NP': 9, 'B-VP': 3, 'O': 4},
#  'JJS': {'I-ADVP': 35,
#   'I-NP': 276,
#   'B-NP': 47,
#   'B-ADJP': 7,
#   'B-ADVP': 4,
#   'I-ADJP': 1,
#   'I-VP': 2,
#   'O': 1,
#   'B-PP': 1},
#  'WP': {'B-NP': 525, 'I-NP': 3, 'O': 1},
#  'RBR': {'B-NP': 61,
#   'B-ADVP': 139,
#   'B-ADJP': 53,
#   'I-ADJP': 15,
#   'O': 1,
#   'I-NP': 34,
#   'I-VP': 5,
#   'I-ADVP': 8,
#   'B-VP': 2,
#   'B-PP': 3},
#  'JJR': {'B-NP': 382,
#   'B-ADJP': 111,
#   'I-ADJP': 45,
#   'B-ADVP': 63,
#   'I-ADVP': 17,
#   'B-VP': 2,
#   'I-NP': 204,
#   'I-VP': 11,
#   'O': 16,
#   'B-PP': 2},
#  'WDT': {'B-NP': 949, 'B-SBAR': 5, 'B-ADVP': 1},
#  'WRB': {'B-ADVP': 447,
#   'B-NP': 17,
#   'I-ADVP': 5,
#   'B-ADJP': 6,
#   'O': 1,
#   'I-NP': 2},
#  'RBS': {'B-NP': 82,
#   'I-NP': 74,
#   'B-VP': 4,
#   'I-ADVP': 1,
#   'B-ADVP': 13,
#   'B-ADJP': 12,
#   'I-VP': 5},
#  'PDT': {'B-NP': 44, 'I-NP': 6, 'O': 5},
#  'RP': {'B-PRT': 71, 'B-PP': 9, 'B-ADVP': 3},
#  ':': {'O': 1031, 'B-NP': 8, 'B-PP': 2, 'I-NP': 5, 'B-ADVP': 1},
#  'FW': {'I-NP': 28, 'I-ADVP': 2, 'B-NP': 7, 'I-ADJP': 1},
#  'WP$': {'B-NP': 35},
#  'SYM': {'O': 4, 'B-VP': 2},
#  'UH': {'B-ADVP': 2, 'B-INTJ': 8, 'I-INTJ': 2, 'I-NP': 3}}

# %%
chunk_dist['NN']
# Out:
# {'B-NP': 5160,
#  'I-NP': 24456,
#  'B-VP': 257,
#  'B-ADJP': 44,
#  'B-ADVP': 38,
#  'O': 37,
#  'B-PP': 15,
#  'I-ADVP': 11,
#  'I-ADJP': 41,
#  'I-VP': 77,
#  'B-INTJ': 1,
#  'B-LST': 2,
#  'B-UCP': 2,
#  'I-UCP': 2,
#  'B-PRT': 2,
#  'I-INTJ': 2}

# %%
for pos in chunk_dist:
    #for chunk in chunk_dist[pos]:
    print(chunk_dist[pos])
# Out:
# {'B-NP': 5160, 'I-NP': 24456, 'B-VP': 257, 'B-ADJP': 44, 'B-ADVP': 38, 'O': 37, 'B-PP': 15, 'I-ADVP': 11, 'I-ADJP': 41, 'I-VP': 77, 'B-INTJ': 1, 'B-LST': 2, 'B-UCP': 2, 'I-UCP': 2, 'B-PRT': 2, 'I-INTJ': 2}
# {'B-PP': 18683, 'B-SBAR': 2112, 'B-ADVP': 396, 'I-NP': 216, 'I-SBAR': 68, 'I-PP': 250, 'B-PRT': 404, 'B-NP': 418, 'B-ADJP': 31, 'O': 88, 'I-VP': 20, 'I-CONJP': 35, 'I-ADJP': 12, 'B-CONJP': 4, 'I-ADVP': 24, 'B-VP': 3}
# {'B-NP': 17807, 'O': 135, 'I-NP': 299, 'B-ADVP': 24, 'I-VP': 7, 'B-VP': 4, 'B-INTJ': 6, 'B-SBAR': 20, 'I-SBAR': 2, 'I-ADVP': 15, 'B-ADJP': 8, 'I-PP': 1, 'B-LST': 1, 'B-PP': 5, 'I-INTJ': 1}
# {'B-VP': 4469, 'I-NP': 76, 'I-INTJ': 2, 'I-VP': 31, 'O': 20, 'B-NP': 49, 'B-ADVP': 1}
# {'I-VP': 1258, 'B-ADVP': 2890, 'I-ADVP': 250, 'I-NP': 307, 'B-ADJP': 399, 'B-NP': 621, 'B-SBAR': 68, 'B-PP': 72, 'I-PP': 9, 'O': 344, 'B-VP': 178, 'I-ADJP': 47, 'B-CONJP': 46, 'I-CONJP': 38, 'B-PRT': 74, 'B-INTJ': 5, 'I-PRT': 1}
# {'I-VP': 2806, 'I-NP': 453, 'B-VP': 1094, 'B-PP': 78, 'I-ADJP': 44, 'B-NP': 187, 'B-ADJP': 92, 'B-ADVP': 1, 'O': 7, 'I-ADVP': 1}
# {'I-VP': 1110, 'B-PP': 2013, 'B-VP': 1822, 'I-NP': 90, 'I-ADVP': 5, 'B-ADVP': 2, 'I-ADJP': 1, 'O': 33, 'I-PP': 5}
# {'I-VP': 5388, 'B-VP': 434, 'B-NP': 124, 'B-INTJ': 2, 'I-NP': 39, 'B-ADJP': 4, 'I-ADJP': 3, 'I-ADVP': 3, 'B-PP': 6, 'O': 8, 'B-PRT': 2, 'B-ADVP': 4}
# {'I-NP': 6771, 'B-ADJP': 1210, 'B-NP': 4304, 'I-ADJP': 383, 'B-ADVP': 159, 'B-VP': 47, 'B-PP': 92, 'O': 37, 'I-ADVP': 27, 'I-VP': 49, 'B-INTJ': 2, 'I-PP': 1, 'B-PRT': 2, 'B-SBAR': 1}
# {'I-NP': 9996, 'B-NP': 3464, 'B-VP': 142, 'I-ADVP': 2, 'O': 7, 'I-VP': 4, 'B-ADVP': 1, 'I-ADJP': 2, 'I-UCP': 1}
# {'B-NP': 8314, 'I-NP': 11470, 'O': 57, 'B-VP': 18, 'B-ADVP': 9, 'I-ADVP': 1, 'I-VP': 2, 'B-PRT': 1, 'B-ADJP': 8, 'B-INTJ': 2, 'I-ADJP': 2}
# {'O': 10195, 'I-NP': 512, 'B-PP': 15, 'B-NP': 24, 'B-ADVP': 1, 'I-VP': 9, 'I-ADJP': 5, 'B-ADJP': 2, 'I-INTJ': 2, 'B-VP': 4, 'I-UCP': 1}
# {'I-NP': 1409, 'O': 3676, 'B-ADVP': 3, 'I-ADVP': 30, 'B-ADJP': 2, 'B-PP': 70, 'I-VP': 104, 'I-ADJP': 26, 'B-NP': 18, 'I-PP': 24, 'B-CONJP': 6, 'I-PRT': 1, 'B-VP': 1, 'I-UCP': 2}
# {'B-NP': 1750, 'B-VP': 5, 'I-NP': 12, 'O': 2}
# {'O': 8813, 'I-NP': 14}
# {'B-VP': 2749, 'I-NP': 60, 'I-VP': 24, 'B-NP': 10, 'B-ADVP': 3, 'B-INTJ': 4, 'O': 11, 'B-ADJP': 6, 'B-PP': 1}
# {'B-NP': 188, 'B-VP': 1570, 'I-VP': 955, 'I-NP': 336, 'B-PP': 207, 'I-ADJP': 2, 'B-ADJP': 9, 'I-ADVP': 1, 'I-PP': 1, 'O': 3}
# {'B-NP': 1858, 'I-NP': 19, 'O': 4}
# {'B-NP': 3153, 'I-NP': 5050, 'O': 64, 'B-LST': 7, 'B-ADVP': 6, 'I-ADVP': 3, 'B-ADJP': 24, 'I-ADJP': 6, 'B-VP': 2}
# {'O': 1301, 'I-NP': 156, 'B-NP': 40, 'I-VP': 16, 'B-VP': 7, 'B-ADJP': 5, 'I-ADJP': 2, 'B-PP': 2, 'B-INTJ': 1, 'B-ADVP': 1}
# {'O': 1397, 'I-NP': 83, 'I-VP': 2, 'B-NP': 10, 'B-PP': 1}
# {'B-VP': 6527, 'B-NP': 25, 'I-VP': 113, 'I-ADJP': 5, 'I-NP': 49, 'O': 17, 'B-PP': 4, 'B-ADJP': 5}
# {'B-NP': 189, 'B-ADVP': 15, 'I-ADVP': 2}
# {'B-VP': 2121, 'O': 37, 'I-VP': 4, 'I-NP': 5}
# {'O': 4, 'I-NP': 10, 'B-ADJP': 3, 'B-NP': 19}
# {'O': 263, 'I-NP': 7, 'I-VP': 1, 'B-SBAR': 1, 'B-NP': 2}
# {'B-ADJP': 19, 'B-NP': 1309, 'I-NP': 419, 'O': 3}
# {'O': 275, 'I-NP': 6}
# {'I-NP': 343, 'B-NP': 77}
# {'B-NP': 3804, 'I-NP': 9, 'B-VP': 3, 'O': 4}
# {'I-ADVP': 35, 'I-NP': 276, 'B-NP': 47, 'B-ADJP': 7, 'B-ADVP': 4, 'I-ADJP': 1, 'I-VP': 2, 'O': 1, 'B-PP': 1}
# {'B-NP': 525, 'I-NP': 3, 'O': 1}
# {'B-NP': 61, 'B-ADVP': 139, 'B-ADJP': 53, 'I-ADJP': 15, 'O': 1, 'I-NP': 34, 'I-VP': 5, 'I-ADVP': 8, 'B-VP': 2, 'B-PP': 3}
# {'B-NP': 382, 'B-ADJP': 111, 'I-ADJP': 45, 'B-ADVP': 63, 'I-ADVP': 17, 'B-VP': 2, 'I-NP': 204, 'I-VP': 11, 'O': 16, 'B-PP': 2}
# {'B-NP': 949, 'B-SBAR': 5, 'B-ADVP': 1}
# {'B-ADVP': 447, 'B-NP': 17, 'I-ADVP': 5, 'B-ADJP': 6, 'O': 1, 'I-NP': 2}
# {'B-NP': 82, 'I-NP': 74, 'B-VP': 4, 'I-ADVP': 1, 'B-ADVP': 13, 'B-ADJP': 12, 'I-VP': 5}
# {'B-NP': 44, 'I-NP': 6, 'O': 5}
# {'B-PRT': 71, 'B-PP': 9, 'B-ADVP': 3}
# {'O': 1031, 'B-NP': 8, 'B-PP': 2, 'I-NP': 5, 'B-ADVP': 1}
# {'I-NP': 28, 'I-ADVP': 2, 'B-NP': 7, 'I-ADJP': 1}
# {'B-NP': 35}
# {'O': 4, 'B-VP': 2}
# {'B-ADVP': 2, 'B-INTJ': 8, 'I-INTJ': 2, 'I-NP': 3}

# %% [markdown]
# ### Selecting the POS-chunk associations

# %% [markdown]
# For each part of speech, select the best association. In the example above, you will have (NN, I-NP) as it is the most frequent. You will store the results in a dictionary that you will call `pos_chunk`

# %%
pos_chunk = {}
maxnr = 0
maxchunk = ''
for pos in chunk_dist:
    for chunk in chunk_dist[pos]:
        if chunk_dist[pos][chunk] > maxnr:
            maxnr = chunk_dist[pos][chunk]
            maxchunk = chunk
    pos_chunk[pos] = maxchunk 
    maxnr = 0
    maxchunk = ''

# %%
pos_chunk['NN']
# Out:
# 'I-NP'

# %% [markdown]
# ### Prediction

# %% [markdown]
# Using the resulting associations, apply your chunker to the test file. You will write a `predict(model, corpus)` function, where `model` will be your associations and `corpus`, the test corpus. You will format the test corpus as a dictionary, where you will add a `pchunk` key for each row with a value that will correspond to the predicted chunk.

# %%
def predict(model, corpus):
    # Model is the association and corpus the test corpus # 
    for sentence in corpus:
        for row in sentence:
            row['pchunk'] = model[row['pos']] 
    return corpus

# %% [markdown]
# We load the test corpus

# %%
test_sentences = read_sentences(test_file)
test_corpus = split_rows(test_sentences, column_names)
test_corpus[:2]
# Out:
# [[{'form': 'Rockwell', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'International', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'Corp.', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': "'s", 'pos': 'POS', 'chunk': 'B-NP'},
#   {'form': 'Tulsa', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'unit', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'said', 'pos': 'VBD', 'chunk': 'B-VP'},
#   {'form': 'it', 'pos': 'PRP', 'chunk': 'B-NP'},
#   {'form': 'signed', 'pos': 'VBD', 'chunk': 'B-VP'},
#   {'form': 'a', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'tentative', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'agreement', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'extending', 'pos': 'VBG', 'chunk': 'B-VP'},
#   {'form': 'its', 'pos': 'PRP$', 'chunk': 'B-NP'},
#   {'form': 'contract', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'with', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'Boeing', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'Co.', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'B-VP'},
#   {'form': 'provide', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'structural', 'pos': 'JJ', 'chunk': 'B-NP'},
#   {'form': 'parts', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'Boeing', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': "'s", 'pos': 'POS', 'chunk': 'B-NP'},
#   {'form': '747', 'pos': 'CD', 'chunk': 'I-NP'},
#   {'form': 'jetliners', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'Rockwell', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'said', 'pos': 'VBD', 'chunk': 'B-VP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'agreement', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'calls', 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-SBAR'},
#   {'form': 'it', 'pos': 'PRP', 'chunk': 'B-NP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'B-VP'},
#   {'form': 'supply', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': '200', 'pos': 'CD', 'chunk': 'B-NP'},
#   {'form': 'additional', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'so-called', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'shipsets', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'planes', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}]]

# %% [markdown]
# We predict the groups. You should have added a `pchunk` key

# %%
predicted_test_corpus = predict(pos_chunk, test_corpus)
predicted_test_corpus[:1]
# Out:
# [[{'form': 'Rockwell', 'pos': 'NNP', 'chunk': 'B-NP', 'pchunk': 'I-NP'},
#   {'form': 'International', 'pos': 'NNP', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': 'Corp.', 'pos': 'NNP', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': "'s", 'pos': 'POS', 'chunk': 'B-NP', 'pchunk': 'B-NP'},
#   {'form': 'Tulsa', 'pos': 'NNP', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': 'unit', 'pos': 'NN', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': 'said', 'pos': 'VBD', 'chunk': 'B-VP', 'pchunk': 'B-VP'},
#   {'form': 'it', 'pos': 'PRP', 'chunk': 'B-NP', 'pchunk': 'B-NP'},
#   {'form': 'signed', 'pos': 'VBD', 'chunk': 'B-VP', 'pchunk': 'B-VP'},
#   {'form': 'a', 'pos': 'DT', 'chunk': 'B-NP', 'pchunk': 'B-NP'},
#   {'form': 'tentative', 'pos': 'JJ', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': 'agreement', 'pos': 'NN', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': 'extending', 'pos': 'VBG', 'chunk': 'B-VP', 'pchunk': 'B-VP'},
#   {'form': 'its', 'pos': 'PRP$', 'chunk': 'B-NP', 'pchunk': 'B-NP'},
#   {'form': 'contract', 'pos': 'NN', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': 'with', 'pos': 'IN', 'chunk': 'B-PP', 'pchunk': 'B-PP'},
#   {'form': 'Boeing', 'pos': 'NNP', 'chunk': 'B-NP', 'pchunk': 'I-NP'},
#   {'form': 'Co.', 'pos': 'NNP', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'B-VP', 'pchunk': 'B-PP'},
#   {'form': 'provide', 'pos': 'VB', 'chunk': 'I-VP', 'pchunk': 'I-VP'},
#   {'form': 'structural', 'pos': 'JJ', 'chunk': 'B-NP', 'pchunk': 'I-NP'},
#   {'form': 'parts', 'pos': 'NNS', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-PP', 'pchunk': 'B-PP'},
#   {'form': 'Boeing', 'pos': 'NNP', 'chunk': 'B-NP', 'pchunk': 'I-NP'},
#   {'form': "'s", 'pos': 'POS', 'chunk': 'B-NP', 'pchunk': 'B-NP'},
#   {'form': '747', 'pos': 'CD', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': 'jetliners', 'pos': 'NNS', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O', 'pchunk': 'O'}]]

# %% [markdown]
# ### Accuracy

# %% [markdown]
# We can evaluate the performance of the baseline with the tag accuracy: the percentage of words that receive the correct tag.

# %%
def eval(predicted):
    """
    Evaluates the predicted chunk accuracy
    :param predicted:
    :return:
    """
    word_cnt = 0
    correct = 0
    for sentence in predicted:
        for row in sentence:
            word_cnt += 1
            if row['chunk'] == row['pchunk']:
                correct += 1
    return correct / word_cnt

# %%
accuracy = eval(predicted_test_corpus)
accuracy
# Out:
# 0.7729066846782194

# %% [markdown]
# ### The CoNLL evaluation

# %% [markdown]
# The accuracy is very misleading as it is biased by the most frequent tags. It is not a good way to evaluate chunking. Instead, CoNLL computes the F1 score of all the chunks with a specific evaluation script.

# %% [markdown]
# #### Saving the corpus

# %% [markdown]
# To use the CoNLL evaluation script, you will store your results in an output file that has four columns. The three first columns will be the input columns from the test file:
# * word,
# * part of speech, and
# * gold-standard chunk.
#
# You will append the predicted chunk as the 4th column. Your output file should look like the excerpt below:
# ```
# Rockwell NNP B-NP I-NP
# International NNP I-NP I-NP
# Corp. NNP I-NP I-NP
# 's POS B-NP B-NP
# Tulsa NNP I-NP I-NP
# unit NN I-NP I-NP
# said VBD B-VP B-VP
# it PRP B-NP B-NP
# ```
# The separator is the space.

# %% [markdown]
# You will use a `save_results(output_dict, keys, output_file)` function, where the keys will be `['form', 'pos', 'chunk', 'pchunk']`

# %%
keys = ['form', 'pos', 'chunk', 'pchunk']

# %%
def save_results(output_dict, keys, output_file):
    f_out = open(output_file, 'w')
    # We write the word (form), part of speech (pos),
    # gold-standard chunk (chunk), and predicted chunk (pchunk)
    for sentence in output_dict:
        for row in sentence:
            for key in keys:
                f_out.write(row[key] + ' ')
            f_out.write('\n')
        f_out.write('\n')
    f_out.close()
    return

# %%
save_results(predicted_test_corpus, keys, 'out')

# %% [markdown]
# The CoNLL 2000 evaluation script will use these two last columns, chunk and predicted chunk, to compute the performance.

# %% [markdown]
# ### Evaluation

# %% [markdown]
# To evaluate your results, you have two options:
# 1. Use the original conlleval script here:  <a href="https://www.clips.uantwerpen.be/conll2000/chunking/"><tt>conlleval.txt</tt></a>.
# 2. Use a Python translation of it.
#
# You will use the second option and you will describe the results you obtained in your report

# %% [markdown]
# #### The Python translation

# %% [markdown]
# Install the script with:
# ```
# pip install conlleval
# ```
# from https://github.com/kaniblu/conlleval
# and run the cell below

# %%
pip install conlleval
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting conlleval
#   Downloading conlleval-0.2-py3-none-any.whl (5.4 kB)
# Installing collected packages: conlleval
# Successfully installed conlleval-0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import conlleval
lines = open('out').read().splitlines()
res = conlleval.evaluate(lines)
baseline_score = res['overall']['chunks']['evals']['f1']

# %%
baseline_score
# Out:
# 0.770671072299583

# %% [markdown]
# ### The official script

# %% [markdown]
# You may want to double-check your results with the original CoNLL script. It is more complex to use however:
# * <tt>conlleval.txt</tt> is the official CoNLL Perl script. It expects the two last columns of the test set to be the manually assigned chunk (gold standard) and the predicted chunk.
# * <tt>conlleval.txt</tt> was written for Unix and if you run Windows, you will have to use a terminal command. In the File menu of the notebook, select New and then Terminal.
# * Start it like this: ` $ conlleval.txt <out` where the `out` file contains both the gold and predicted chunk tags. `conlleval.txt` is a Perl script.
# * Perl is installed on most Unix distributions. If it is not installed on your machine, you need to install it. Make also sure that you have the execution rights. Otherwise change them with: `$ chmod +x conlleval.txt`
# * The `conlleval.txt` script expects the new lines to be `\n` as in Unix. If you run your Python program on Windows, your new lines will be `\r\n`. To have the correct new lines, add this parameter to `open()`: `newline='\n’` like this: `f_out = open('out', ‘w’, newline='\n’)`
# * The complete description of the CoNLL 2000 evaluation script is available here: [https://www.clips.uantwerpen.be/conll2000/chunking/output.html](https://www.clips.uantwerpen.be/conll2000/chunking/output.html)

# %% [markdown]
# ## Using Machine Learning: A first ML program

# %% [markdown]
# In this exercise, you will apply and explore a machine-learning program.
#
# The program that won the CoNLL 2000 shared task (Kudoh and Matsumoto, 2000) used a window of five words around the chunk tag to identify, $c_i$. They built a feature vector consisting of:
# 1. The values of the five words in this window: $w_{i-2}, w_{i-1}, w_{i}, w_{i+1}, w_{i+2}$
# 2. The values of the five parts of speech in this window: $t_{i-2}, t_{i-1}, t_{i}, t_{i+1}, t_{i+2}$
# 3. The values of the two previous chunk tags in the first part of the window: $c_{i-2}, c_{i-1}$
#
# The two last parameters (3.) are said to be dynamic because the program computes them at run-time. Read [Kudoh and Matsumoto's paper](http://www.clips.uantwerpen.be/conll2000/pdf/14244kud.pdf) and the [Yamcha](http://www.chasen.org/~taku/software/yamcha/) software site.
#
# You will start with a given code that uses the two first sets of features (1. and 2.) and add yourself the last one (3.) to improve the performance of your chunker. Kudoh and Matsumoto trained a classifier based on support vector machines. You will use logistic regression.

# %% [markdown]
# ### Imports

# %%
import bs4
import os
import requests
from sklearn.feature_extraction import DictVectorizer
from sklearn import svm
from sklearn import linear_model
from sklearn import metrics
from sklearn import tree
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import GridSearchCV
import time

# %% [markdown]
# ### Feature extraction

# %% [markdown]
# #### Functions

# %% [markdown]
# A first function to extract features from one sentence

# %%
def extract_features_sent_static(sentence, w_size, feature_names):
    """
    Extract the features from one sentence
    returns X and y, where X is a list of dictionaries and
    y is a list of symbols
    :param sentence: string containing the CoNLL structure of a sentence
    :param w_size:
    :return:
    """

    # We pad the sentence to extract the context window more easily
    start = [{'form': 'BOS', 'pos': 'BOS', 'chunk': 'BOS'}]
    end = [{'form': 'EOS', 'pos': 'EOS', 'chunk': 'EOS'}]
    start *= w_size
    end *= w_size
    padded_sentence = start + sentence
    padded_sentence += end

    # We extract the features and the classes
    # X contains is a list of features, where each feature vector is a dictionary
    # y is the list of classes
    X = list()
    y = list()
    for i in range(len(padded_sentence) - 2 * w_size):
        # x is a row of X
        x = list()
        # The words in lower case
        for j in range(2 * w_size + 1):
            x.append(padded_sentence[i + j]['form'].lower())
        # The POS
        for j in range(2 * w_size + 1):
            x.append(padded_sentence[i + j]['pos'])
        # The chunks (Up to the word)
        """
        for j in range(w_size):
            feature_line.append(padded_sentence[i + j]['chunk'])
        """
        # We represent the feature vector as a dictionary
        X.append(dict(zip(feature_names, x)))
        # The classes are stored in a list
        y.append(padded_sentence[i + w_size]['chunk'])
    return X, y

# %% [markdown]
# And from all the sentences

# %%
def extract_features_static(sentences, w_size, feature_names):
    """
    Builds X matrix and y vector
    X is a list of dictionaries and y is a list
    :param sentences:
    :param w_size:
    :return:
    """
    X_l = []
    y_l = []
    for sentence in sentences:
        X, y = extract_features_sent_static(sentence, w_size, feature_names)
        X_l.extend(X)
        y_l.extend(y)
    return X_l, y_l

# %% [markdown]
# #### Applying the feature extraction

# %% [markdown]
# The size of the window and the names of the features

# %%
w_size = 2  # The size of the context window to the left and right of the word
feature_names = ['word_n2', 'word_n1', 'word', 'word_p1', 'word_p2',
                 'pos_n2', 'pos_n1', 'pos', 'pos_p1', 'pos_p2']

# %% [markdown]
# We read the corpus and format it as a dictionary

# %%
train_sentences = read_sentences(train_file)
train_corpus = split_rows(train_sentences, column_names)

# %%
train_corpus[:2]
# Out:
# [[{'form': 'Confidence', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'in', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'pound', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'is', 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'widely', 'pos': 'RB', 'chunk': 'I-VP'},
#   {'form': 'expected', 'pos': 'VBN', 'chunk': 'I-VP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'I-VP'},
#   {'form': 'take', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'another', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'sharp', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'dive', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'if', 'pos': 'IN', 'chunk': 'B-SBAR'},
#   {'form': 'trade', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'figures', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'September', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'due', 'pos': 'JJ', 'chunk': 'B-ADJP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'release', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'tomorrow', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'fail', 'pos': 'VB', 'chunk': 'B-VP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'I-VP'},
#   {'form': 'show', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'a', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'substantial', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'improvement', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'from', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'July', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'and', 'pos': 'CC', 'chunk': 'I-NP'},
#   {'form': 'August', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': "'s", 'pos': 'POS', 'chunk': 'B-NP'},
#   {'form': 'near-record', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'deficits', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'Chancellor', 'pos': 'NNP', 'chunk': 'O'},
#   {'form': 'of', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'Exchequer', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'Nigel', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'Lawson', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': "'s", 'pos': 'POS', 'chunk': 'B-NP'},
#   {'form': 'restated', 'pos': 'VBN', 'chunk': 'I-NP'},
#   {'form': 'commitment', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'B-PP'},
#   {'form': 'a', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'firm', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'monetary', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'policy', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'has', 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'helped', 'pos': 'VBN', 'chunk': 'I-VP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'I-VP'},
#   {'form': 'prevent', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'a', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'freefall', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'in', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'sterling', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'over', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'past', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'week', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}]]

# %%
X_dict, y = extract_features_static(train_corpus, w_size, feature_names)
X_dict[:2]
# Out:
# [{'word_n2': 'bos',
#   'word_n1': 'bos',
#   'word': 'confidence',
#   'word_p1': 'in',
#   'word_p2': 'the',
#   'pos_n2': 'BOS',
#   'pos_n1': 'BOS',
#   'pos': 'NN',
#   'pos_p1': 'IN',
#   'pos_p2': 'DT'},
#  {'word_n2': 'bos',
#   'word_n1': 'confidence',
#   'word': 'in',
#   'word_p1': 'the',
#   'word_p2': 'pound',
#   'pos_n2': 'BOS',
#   'pos_n1': 'NN',
#   'pos': 'IN',
#   'pos_p1': 'DT',
#   'pos_p2': 'NN'}]

# %%
y[:2]
# Out:
# ['B-NP', 'B-PP']

# %% [markdown]
# ### Feature encoding

# %%
# Vectorize the feature matrix and carry out a one-hot encoding
vec = DictVectorizer(sparse=True)
X = vec.fit_transform(X_dict)

# %% [markdown]
# ### Training the model

# %%
classifier = linear_model.LogisticRegression()
model = classifier.fit(X, y)
model
# Out:
# /Users/feliciasegui/Library/Python/3.7/lib/python/site-packages/sklearn/linear_model/_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression()

# %% [markdown]
# ### Predicting the test set

# %% [markdown]
# We read the sentences and create a dictionary

# %%
test_sentences = read_sentences(test_file)
test_corpus = split_rows(test_sentences, column_names)
test_corpus[:2]
# Out:
# [[{'form': 'Rockwell', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'International', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'Corp.', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': "'s", 'pos': 'POS', 'chunk': 'B-NP'},
#   {'form': 'Tulsa', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'unit', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'said', 'pos': 'VBD', 'chunk': 'B-VP'},
#   {'form': 'it', 'pos': 'PRP', 'chunk': 'B-NP'},
#   {'form': 'signed', 'pos': 'VBD', 'chunk': 'B-VP'},
#   {'form': 'a', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'tentative', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'agreement', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'extending', 'pos': 'VBG', 'chunk': 'B-VP'},
#   {'form': 'its', 'pos': 'PRP$', 'chunk': 'B-NP'},
#   {'form': 'contract', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'with', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'Boeing', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'Co.', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'B-VP'},
#   {'form': 'provide', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'structural', 'pos': 'JJ', 'chunk': 'B-NP'},
#   {'form': 'parts', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'Boeing', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': "'s", 'pos': 'POS', 'chunk': 'B-NP'},
#   {'form': '747', 'pos': 'CD', 'chunk': 'I-NP'},
#   {'form': 'jetliners', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'Rockwell', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'said', 'pos': 'VBD', 'chunk': 'B-VP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'agreement', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'calls', 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-SBAR'},
#   {'form': 'it', 'pos': 'PRP', 'chunk': 'B-NP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'B-VP'},
#   {'form': 'supply', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': '200', 'pos': 'CD', 'chunk': 'B-NP'},
#   {'form': 'additional', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'so-called', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'shipsets', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'planes', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}]]

# %% [markdown]
# We extract the features

# %%
X_test_dict, y_test = extract_features_static(test_corpus, w_size, feature_names)
X_test_dict[:2]
# Out:
# [{'word_n2': 'bos',
#   'word_n1': 'bos',
#   'word': 'rockwell',
#   'word_p1': 'international',
#   'word_p2': 'corp.',
#   'pos_n2': 'BOS',
#   'pos_n1': 'BOS',
#   'pos': 'NNP',
#   'pos_p1': 'NNP',
#   'pos_p2': 'NNP'},
#  {'word_n2': 'bos',
#   'word_n1': 'rockwell',
#   'word': 'international',
#   'word_p1': 'corp.',
#   'word_p2': "'s",
#   'pos_n2': 'BOS',
#   'pos_n1': 'NNP',
#   'pos': 'NNP',
#   'pos_p1': 'NNP',
#   'pos_p2': 'POS'}]

# %%
y_test[:2]
# Out:
# ['B-NP', 'I-NP']

# %% [markdown]
# We vectorize the features

# %%
X_test = vec.transform(X_test_dict)  # Possible to add: .toarray()

# %% [markdown]
# And we predict the test set

# %%
y_test_predicted = classifier.predict(X_test)
y_test_predicted[:2]
# Out:
# array(['B-NP', 'I-NP'], dtype='<U7')

# %% [markdown]
# We now add the predicted chunks to the sentences

# %%
inx = 0
for sentence in test_corpus:
    for word in sentence:
        word['pchunk'] = y_test_predicted[inx]
        inx += 1

# %% [markdown]
# The index sould be equal to the length of the prediction

# %%
print(inx)
len(y_test_predicted)
# Out:
# 47377
# 47377

# %%
test_corpus[:2]
# Out:
# [[{'form': 'Rockwell', 'pos': 'NNP', 'chunk': 'B-NP', 'pchunk': 'B-NP'},
#   {'form': 'International', 'pos': 'NNP', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': 'Corp.', 'pos': 'NNP', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': "'s", 'pos': 'POS', 'chunk': 'B-NP', 'pchunk': 'B-NP'},
#   {'form': 'Tulsa', 'pos': 'NNP', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': 'unit', 'pos': 'NN', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': 'said', 'pos': 'VBD', 'chunk': 'B-VP', 'pchunk': 'B-VP'},
#   {'form': 'it', 'pos': 'PRP', 'chunk': 'B-NP', 'pchunk': 'B-NP'},
#   {'form': 'signed', 'pos': 'VBD', 'chunk': 'B-VP', 'pchunk': 'B-VP'},
#   {'form': 'a', 'pos': 'DT', 'chunk': 'B-NP', 'pchunk': 'B-NP'},
#   {'form': 'tentative', 'pos': 'JJ', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': 'agreement', 'pos': 'NN', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': 'extending', 'pos': 'VBG', 'chunk': 'B-VP', 'pchunk': 'B-VP'},
#   {'form': 'its', 'pos': 'PRP$', 'chunk': 'B-NP', 'pchunk': 'B-NP'},
#   {'form': 'contract', 'pos': 'NN', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': 'with', 'pos': 'IN', 'chunk': 'B-PP', 'pchunk': 'B-PP'},
#   {'form': 'Boeing', 'pos': 'NNP', 'chunk': 'B-NP', 'pchunk': 'B-NP'},
#   {'form': 'Co.', 'pos': 'NNP', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'B-VP', 'pchunk': 'B-VP'},
#   {'form': 'provide', 'pos': 'VB', 'chunk': 'I-VP', 'pchunk': 'I-VP'},
#   {'form': 'structural', 'pos': 'JJ', 'chunk': 'B-NP', 'pchunk': 'B-NP'},
#   {'form': 'parts', 'pos': 'NNS', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-PP', 'pchunk': 'B-PP'},
#   {'form': 'Boeing', 'pos': 'NNP', 'chunk': 'B-NP', 'pchunk': 'B-NP'},
#   {'form': "'s", 'pos': 'POS', 'chunk': 'B-NP', 'pchunk': 'B-NP'},
#   {'form': '747', 'pos': 'CD', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': 'jetliners', 'pos': 'NNS', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O', 'pchunk': 'O'}],
#  [{'form': 'Rockwell', 'pos': 'NNP', 'chunk': 'B-NP', 'pchunk': 'B-NP'},
#   {'form': 'said', 'pos': 'VBD', 'chunk': 'B-VP', 'pchunk': 'B-VP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP', 'pchunk': 'B-NP'},
#   {'form': 'agreement', 'pos': 'NN', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': 'calls', 'pos': 'VBZ', 'chunk': 'B-VP', 'pchunk': 'B-VP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-SBAR', 'pchunk': 'B-SBAR'},
#   {'form': 'it', 'pos': 'PRP', 'chunk': 'B-NP', 'pchunk': 'B-NP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'B-VP', 'pchunk': 'B-VP'},
#   {'form': 'supply', 'pos': 'VB', 'chunk': 'I-VP', 'pchunk': 'I-VP'},
#   {'form': '200', 'pos': 'CD', 'chunk': 'B-NP', 'pchunk': 'B-NP'},
#   {'form': 'additional', 'pos': 'JJ', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': 'so-called', 'pos': 'JJ', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': 'shipsets', 'pos': 'NNS', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-PP', 'pchunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP', 'pchunk': 'B-NP'},
#   {'form': 'planes', 'pos': 'NNS', 'chunk': 'I-NP', 'pchunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O', 'pchunk': 'O'}]]

# %%
save_results(test_corpus, keys, 'out')

# %% [markdown]
# #### Evaluating the performance

# %%
lines = open('out').read().splitlines()
res = conlleval.evaluate(lines)
simple_ml_score = res['overall']['chunks']['evals']['f1']

# %%
simple_ml_score
# Out:
# 0.9157688948047087

# %% [markdown]
# ### Question on the ML program

# %% [markdown]
# 1. What is the feature vector that corresponds to the <tt>ml_chunker.py</tt> program? Is it the same Kudoh
#     and Matsumoto used in their experiment?
# 2. What is the performance of the chunker?
# 3. Remove the lexical features (the words) from the feature vector and measure the performance. You should
#     observe a decrease.
# 4. What is the classifier used in the program?
# 5. As an optional task, you may try two other classifiers from sklearn and measure their performance: decision trees, perceptron, support vector machines, etc. Be aware that support vector machines take a long time to train: up to one hour.

# %% [markdown]
# ## Using Machine Learning: Adding all the features from Kudoh and Matsumoto

# %% [markdown]
# Complement the feature vector used in the previous section with the two dynamic features, $c_{i-2}, c_{i-1}$, and train a new model. You will need to write a new `extract_features_sent_dyn` and `predict` functions.
# In his experiments, your teacher obtained a F1 score of 92.65 with logistic regression and the default parameters from sklearn, i.e. `linear_model.LogisticRegression()`;

# %% [markdown]
# **A frequent mistake in the labs** is to use the gold-standard chunks from the test set. Be aware that  when you predict the test set, you do not know the dynamic features in advance and you must  not use the ones from the test file. You will use the two previous chunk tags that you have predicted.

# %% [markdown]
# You need to reach a global F1 score of 92 to pass this laboratory.

# %%
def extract_features_dyn(sentences, w_size, feature_names):
    """
    Builds X matrix and y vector
    X is a list of dictionaries and y is a list
    :param sentences:
    :param w_size:
    :return:
    """
    X_l = []
    y_l = []
    for sentence in sentences:
        X, y = extract_features_sent_dyn(sentence, w_size, feature_names)
        X_l.extend(X)
        y_l.extend(y)
    return X_l, y_l

# %%
def extract_features_sent_dyn(sentence, w_size, feature_names):
    """
    Extract the features from one sentence
    returns X and y, where X is a list of dictionaries and
    y is a list of symbols
    :param sentence: string containing the CoNLL structure of a sentence
    :param w_size:
    :return:
    """

    # We pad the sentence to extract the context window more easily
    start = [{'form': 'BOS', 'pos': 'BOS', 'chunk': 'BOS'}]
    end = [{'form': 'EOS', 'pos': 'EOS', 'chunk': 'EOS'}]
    start *= w_size
    #padded_sentence = start + start + start
    end *= w_size
    padded_sentence = start + sentence
    padded_sentence += end

    # We extract the features and the classes
    # X contains is a list of features, where each feature vector is a dictionary
    # y is the list of classes
    X_l = list()
    y_l = list()
    for i in range(len(padded_sentence) - 2 * w_size):
        # x is a row of X
        x = list()
        # The words in lower case
        for j in range(2 * w_size + 1):
            x.append(padded_sentence[i + j]['form'].lower())
        # The POS
        for j in range(2 * w_size + 1):
            x.append(padded_sentence[i + j]['pos'])
        # The chunks (Up to the word)
    
        for j in range(w_size):
            x.append(padded_sentence[i + j]['chunk'])
        
        # We represent the feature vector as a dictionary
        X_l.append(dict(zip(feature_names, x)))
        # The classes are stored in a list
        y_l.append(padded_sentence[i + w_size]['chunk'])
    return X_l, y_l

# %%
feature_names_dyn = ['word_n2', 'word_n1', 'word', 'word_p1', 'word_p2',
                     'pos_n2', 'pos_n1', 'pos', 'pos_p1', 'pos_p2', 'chunk_n2',
                     'chunk_n1']

# %%
train_sentences = read_sentences(train_file)
train_corpus = split_rows(train_sentences, column_names)
train_corpus[:2]
# Out:
# [[{'form': 'Confidence', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'in', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'pound', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'is', 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'widely', 'pos': 'RB', 'chunk': 'I-VP'},
#   {'form': 'expected', 'pos': 'VBN', 'chunk': 'I-VP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'I-VP'},
#   {'form': 'take', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'another', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'sharp', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'dive', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'if', 'pos': 'IN', 'chunk': 'B-SBAR'},
#   {'form': 'trade', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'figures', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'September', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'due', 'pos': 'JJ', 'chunk': 'B-ADJP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'release', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'tomorrow', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'fail', 'pos': 'VB', 'chunk': 'B-VP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'I-VP'},
#   {'form': 'show', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'a', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'substantial', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'improvement', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'from', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'July', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'and', 'pos': 'CC', 'chunk': 'I-NP'},
#   {'form': 'August', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': "'s", 'pos': 'POS', 'chunk': 'B-NP'},
#   {'form': 'near-record', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'deficits', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'Chancellor', 'pos': 'NNP', 'chunk': 'O'},
#   {'form': 'of', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'Exchequer', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'Nigel', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'Lawson', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': "'s", 'pos': 'POS', 'chunk': 'B-NP'},
#   {'form': 'restated', 'pos': 'VBN', 'chunk': 'I-NP'},
#   {'form': 'commitment', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'B-PP'},
#   {'form': 'a', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'firm', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'monetary', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'policy', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'has', 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'helped', 'pos': 'VBN', 'chunk': 'I-VP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'I-VP'},
#   {'form': 'prevent', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'a', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'freefall', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'in', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'sterling', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'over', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'past', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'week', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}]]

# %%
X_dict, y = extract_features_dyn(train_corpus, w_size, feature_names_dyn)

# %%
X_dict[:3]
# Out:
# [{'word_n2': 'bos',
#   'word_n1': 'bos',
#   'word': 'confidence',
#   'word_p1': 'in',
#   'word_p2': 'the',
#   'pos_n2': 'BOS',
#   'pos_n1': 'BOS',
#   'pos': 'NN',
#   'pos_p1': 'IN',
#   'pos_p2': 'DT',
#   'chunk_n2': 'BOS',
#   'chunk_n1': 'BOS'},
#  {'word_n2': 'bos',
#   'word_n1': 'confidence',
#   'word': 'in',
#   'word_p1': 'the',
#   'word_p2': 'pound',
#   'pos_n2': 'BOS',
#   'pos_n1': 'NN',
#   'pos': 'IN',
#   'pos_p1': 'DT',
#   'pos_p2': 'NN',
#   'chunk_n2': 'BOS',
#   'chunk_n1': 'B-NP'},
#  {'word_n2': 'confidence',
#   'word_n1': 'in',
#   'word': 'the',
#   'word_p1': 'pound',
#   'word_p2': 'is',
#   'pos_n2': 'NN',
#   'pos_n1': 'IN',
#   'pos': 'DT',
#   'pos_p1': 'NN',
#   'pos_p2': 'VBZ',
#   'chunk_n2': 'B-NP',
#   'chunk_n1': 'B-PP'}]

# %% [markdown]
# You will now vectorize the training set

# %%
v = DictVectorizer(sparse = True)
X = v.fit_transform(X_dict)

# %%
classifier = linear_model.LogisticRegression()
model = classifier.fit(X, y)
model
# Out:
# /Users/feliciasegui/Library/Python/3.7/lib/python/site-packages/sklearn/linear_model/_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression()

# %% [markdown]
# And fit the model

# %% [markdown]
# ### Prediction

# %% [markdown]
# You will finally predict the test set. We load the corpus again.

# %%
test_sentences = read_sentences(test_file)
test_corpus = split_rows(test_sentences, column_names)
test_corpus[:3]
# Out:
# [[{'form': 'Rockwell', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'International', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'Corp.', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': "'s", 'pos': 'POS', 'chunk': 'B-NP'},
#   {'form': 'Tulsa', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'unit', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'said', 'pos': 'VBD', 'chunk': 'B-VP'},
#   {'form': 'it', 'pos': 'PRP', 'chunk': 'B-NP'},
#   {'form': 'signed', 'pos': 'VBD', 'chunk': 'B-VP'},
#   {'form': 'a', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'tentative', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'agreement', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'extending', 'pos': 'VBG', 'chunk': 'B-VP'},
#   {'form': 'its', 'pos': 'PRP$', 'chunk': 'B-NP'},
#   {'form': 'contract', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'with', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'Boeing', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'Co.', 'pos': 'NNP', 'chunk': 'I-NP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'B-VP'},
#   {'form': 'provide', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': 'structural', 'pos': 'JJ', 'chunk': 'B-NP'},
#   {'form': 'parts', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'Boeing', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': "'s", 'pos': 'POS', 'chunk': 'B-NP'},
#   {'form': '747', 'pos': 'CD', 'chunk': 'I-NP'},
#   {'form': 'jetliners', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'Rockwell', 'pos': 'NNP', 'chunk': 'B-NP'},
#   {'form': 'said', 'pos': 'VBD', 'chunk': 'B-VP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'agreement', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'calls', 'pos': 'VBZ', 'chunk': 'B-VP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-SBAR'},
#   {'form': 'it', 'pos': 'PRP', 'chunk': 'B-NP'},
#   {'form': 'to', 'pos': 'TO', 'chunk': 'B-VP'},
#   {'form': 'supply', 'pos': 'VB', 'chunk': 'I-VP'},
#   {'form': '200', 'pos': 'CD', 'chunk': 'B-NP'},
#   {'form': 'additional', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'so-called', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'shipsets', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'planes', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}],
#  [{'form': 'These', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'include', 'pos': 'VBP', 'chunk': 'B-VP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'among', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'other', 'pos': 'JJ', 'chunk': 'B-NP'},
#   {'form': 'parts', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'each', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'jetliner', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': "'s", 'pos': 'POS', 'chunk': 'B-NP'},
#   {'form': 'two', 'pos': 'CD', 'chunk': 'I-NP'},
#   {'form': 'major', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'bulkheads', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'a', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'pressure', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'floor', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'torque', 'pos': 'NN', 'chunk': 'B-NP'},
#   {'form': 'box', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': ',', 'pos': ',', 'chunk': 'O'},
#   {'form': 'fixed', 'pos': 'VBN', 'chunk': 'B-NP'},
#   {'form': 'leading', 'pos': 'VBG', 'chunk': 'I-NP'},
#   {'form': 'edges', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'for', 'pos': 'IN', 'chunk': 'B-PP'},
#   {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'wings', 'pos': 'NNS', 'chunk': 'I-NP'},
#   {'form': 'and', 'pos': 'CC', 'chunk': 'O'},
#   {'form': 'an', 'pos': 'DT', 'chunk': 'B-NP'},
#   {'form': 'aft', 'pos': 'JJ', 'chunk': 'I-NP'},
#   {'form': 'keel', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': 'beam', 'pos': 'NN', 'chunk': 'I-NP'},
#   {'form': '.', 'pos': '.', 'chunk': 'O'}]]

# %% [markdown]
# Let us extract the static features from one sentence

# %%
X_test_dict, y_test = extract_features_static([test_corpus[0]], w_size, feature_names)
X_test_dict[:2]
# Out:
# [{'word_n2': 'bos',
#   'word_n1': 'bos',
#   'word': 'rockwell',
#   'word_p1': 'international',
#   'word_p2': 'corp.',
#   'pos_n2': 'BOS',
#   'pos_n1': 'BOS',
#   'pos': 'NNP',
#   'pos_p1': 'NNP',
#   'pos_p2': 'NNP'},
#  {'word_n2': 'bos',
#   'word_n1': 'rockwell',
#   'word': 'international',
#   'word_p1': 'corp.',
#   'word_p2': "'s",
#   'pos_n2': 'BOS',
#   'pos_n1': 'NNP',
#   'pos': 'NNP',
#   'pos_p1': 'NNP',
#   'pos_p2': 'POS'}]

# %% [markdown]
# This $\mathbf{X}\_{\textrm{dict}}$ is incomplete. For the prediction, we need to reinject dynamically the two previously predicted tags to have the full feature vector. Write this code here.
#
# This part is probably the most difficult of the lab. You may want to write it first for one sentence, and then for the test corpus. The prediction will take a longer time and you may want to include a progress bar with this snippet:
# ```
# from tqdm import tqdm
# for test_sentence in tqdm(test_corpus):
# ```

# %%
y_test_predicted_dyn = []
from tqdm import tqdm
cn_1 = 'BOS'
cn_2 = 'BOS'

for test_sentence in tqdm(test_corpus):
    x_test_dict, y_test = extract_features_static([test_sentence], w_size, feature_names)
    counter = 0                                           
    for row in x_test_dict:
        if counter == 0:
            row['chunk_n2'] = cn_2
            row['chunk_n1'] = cn_1
            
        elif counter == 1:
            row['chunk_n2'] = cn_1
            row['chunk_n1'] = y_test_predicted_dyn[-1][0]
        
        else:
            row['chunk_n2'] = y_test_predicted_dyn[-2][0]
            row['chunk_n1'] = y_test_predicted_dyn[-1][0]
        
        x_sample = v.transform(row)
        y_test_predicted_dyn.append(model.predict(x_sample)[0])
        
        counter +=1
# Out:
# 100%|██████████| 2012/2012 [04:45<00:00,  7.04it/s]

# %%
y_test_predicted_dyn[:3]
# Out:
# [array(['B-NP'], dtype='<U7'),
#  array(['I-NP'], dtype='<U7'),
#  array(['I-NP'], dtype='<U7')]

# %%
y_test_predicted_dyn[:3]
# Out:
# ['B-NP', 'I-NP', 'I-NP']

# %%
inx = 0
for sentence in test_corpus:
    for word in sentence:
        word['pchunk'] = y_test_predicted_dyn[inx]
        inx += 1

# %%
save_results(test_corpus, keys, 'out')

# %% [markdown]
# #### Evaluation

# %%
lines = open('out').read().splitlines()
res = conlleval.evaluate(lines)
improved_ml_score = res['overall']['chunks']['evals']['f1']
improved_ml_score
# Out:
# 0.9265266775640221

# %%
lines = open('out').read().splitlines()
res = conlleval.evaluate(lines)
improved_ml_score = res['overall']['chunks']['evals']['f1']
improved_ml_score
# Out:
# 0.9265266775640221

# %% [markdown]
# ### Optional improvement

# %% [markdown]
# As an optional task, you can try to improve the score with beam search. If you know this technique, apply it using the probability output of logistic regression.
#
# With the same classifier and a beam diameter of 5, your teacher obtained 92.87.

# %% [markdown]
# ## Collecting the entities

# %% [markdown]
# You will now collect all the named entities from the training set, defined as NP chunks and starting with a `NNP` (proper noun) or a `NNPS` (proper noun, plural) tag. As an example, in the first sentence of `train_corpus`, you will extract `('September', )` and `('July', 'and', 'August')`. You will set all the tuples in a set that you will call `ne_set`.

# %%
train_corpus[0]
# Out:
# [{'form': 'Confidence', 'pos': 'NN', 'chunk': 'B-NP'},
#  {'form': 'in', 'pos': 'IN', 'chunk': 'B-PP'},
#  {'form': 'the', 'pos': 'DT', 'chunk': 'B-NP'},
#  {'form': 'pound', 'pos': 'NN', 'chunk': 'I-NP'},
#  {'form': 'is', 'pos': 'VBZ', 'chunk': 'B-VP'},
#  {'form': 'widely', 'pos': 'RB', 'chunk': 'I-VP'},
#  {'form': 'expected', 'pos': 'VBN', 'chunk': 'I-VP'},
#  {'form': 'to', 'pos': 'TO', 'chunk': 'I-VP'},
#  {'form': 'take', 'pos': 'VB', 'chunk': 'I-VP'},
#  {'form': 'another', 'pos': 'DT', 'chunk': 'B-NP'},
#  {'form': 'sharp', 'pos': 'JJ', 'chunk': 'I-NP'},
#  {'form': 'dive', 'pos': 'NN', 'chunk': 'I-NP'},
#  {'form': 'if', 'pos': 'IN', 'chunk': 'B-SBAR'},
#  {'form': 'trade', 'pos': 'NN', 'chunk': 'B-NP'},
#  {'form': 'figures', 'pos': 'NNS', 'chunk': 'I-NP'},
#  {'form': 'for', 'pos': 'IN', 'chunk': 'B-PP'},
#  {'form': 'September', 'pos': 'NNP', 'chunk': 'B-NP'},
#  {'form': ',', 'pos': ',', 'chunk': 'O'},
#  {'form': 'due', 'pos': 'JJ', 'chunk': 'B-ADJP'},
#  {'form': 'for', 'pos': 'IN', 'chunk': 'B-PP'},
#  {'form': 'release', 'pos': 'NN', 'chunk': 'B-NP'},
#  {'form': 'tomorrow', 'pos': 'NN', 'chunk': 'B-NP'},
#  {'form': ',', 'pos': ',', 'chunk': 'O'},
#  {'form': 'fail', 'pos': 'VB', 'chunk': 'B-VP'},
#  {'form': 'to', 'pos': 'TO', 'chunk': 'I-VP'},
#  {'form': 'show', 'pos': 'VB', 'chunk': 'I-VP'},
#  {'form': 'a', 'pos': 'DT', 'chunk': 'B-NP'},
#  {'form': 'substantial', 'pos': 'JJ', 'chunk': 'I-NP'},
#  {'form': 'improvement', 'pos': 'NN', 'chunk': 'I-NP'},
#  {'form': 'from', 'pos': 'IN', 'chunk': 'B-PP'},
#  {'form': 'July', 'pos': 'NNP', 'chunk': 'B-NP'},
#  {'form': 'and', 'pos': 'CC', 'chunk': 'I-NP'},
#  {'form': 'August', 'pos': 'NNP', 'chunk': 'I-NP'},
#  {'form': "'s", 'pos': 'POS', 'chunk': 'B-NP'},
#  {'form': 'near-record', 'pos': 'JJ', 'chunk': 'I-NP'},
#  {'form': 'deficits', 'pos': 'NNS', 'chunk': 'I-NP'},
#  {'form': '.', 'pos': '.', 'chunk': 'O'}]

# %% [markdown]
# You can write a two-pass procedure. For each sentence of the corpus:
# 1. In the first pass, you will collect the start indices of the noun groups which are also proper nouns. For the first sentence, it will result in the list `[16, 30]`;
# 2. In the second pass, you will collect the segments, starting at each index. For the first sentence, it will result in the tuples `('September',)`and `('July', 'and', 'August')`
#
# Should you have a better solution, please use it.

# %%
ne_set = set()
templist = []

for sentence in train_corpus:
    b = False
    templist = []
    for row in sentence:
        
        if b == True and row['chunk'] == 'I-NP':
            templist.append(row['form'])
        
        if b == True and row['chunk'] != 'I-NP':
            ne_set.add(tuple(templist))
            templist = []
            b = False
        
        
        if (row['pos'] == 'NNP' or row['pos'] == 'NNPS') and row['chunk'] == 'B-NP':
            templist.append(row['form'])
            b = True
        
    
    if b == True:
        ne_set.add(tuple(templist))

# %%
list(ne_set)
# Out:
# [('Republican-governor\\/Democratic-legislature', 'lines'),
#  ('Alfred', 'Hayes'),
#  ('Cindy', 'Katz'),
#  ('Data', 'General', 'Corp.'),
#  ('Imperial', 'Cup', 'Corp.'),
#  ('British', 'Air', 'shareholders'),
#  ('Robert', 'Cawthorn'),
#  ('Honeywell',),
#  ('Reuters',),
#  ('Mr.', 'Bennett'),
#  ('Chantilly',),
#  ('IMS', 'International'),
#  ('Nac', 'Re', 'Corp.'),
#  ('Prudential', 'Home', 'Mortgage', 'Co.'),
#  ('Pride', 'Petroleum', 'Services', 'Inc.'),
#  ('Aruba',),
#  ('U.S.', 'productivity'),
#  ('AT&T', 'managers'),
#  ('Lipton', 'iced', 'tea'),
#  ('San', 'Juan'),
#  ('Central', 'America'),
#  ('Wacoal', 'Corp.'),
#  ('Money', 'Market', 'Deposits'),
#  ('I.E.P.', 'Securities', 'Ltd.'),
#  ('Saatchi', '&', 'Saatchi', 'Co'),
#  ('George', 'Orwell'),
#  ('Arthur', 'D.', 'Little', 'Inc.'),
#  ('Nov.', '29'),
#  ('Gold', 'and', 'silver', 'broker', 'Preston', 'Semel'),
#  ('USACafes', 'Limited', 'Partnership'),
#  ('Government', 'National', 'Mortgage', 'Association', '9', '%', 'securities'),
#  ('PRINCE', 'HENRI'),
#  ('Prestige', 'U.'),
#  ('Grant',),
#  ('Buffalo',),
#  ('Dreyfus',),
#  ('Southern', 'California'),
#  ('Mr.', 'Byrne'),
#  ('Newark',),
#  ('James', 'Smith'),
#  ('Mr.', 'and', 'Mrs.', 'Peter', 'S.', 'Rubin'),
#  ('Francis', 'Dang'),
#  ('Great', 'Western', 'Financial'),
#  ('National', 'Westminister'),
#  ('Moslems', 'and', 'Christians'),
#  ('NV', 'DSM'),
#  ('Jeff', 'and', 'Beau'),
#  ('Aetna', 'Life', '&', 'Casualty'),
#  ('General', 'Motors'),
#  ('Autodesk',),
#  ('Jan.', '1'),
#  ('Public', 'Service', 'Co.'),
#  ('Sciences',),
#  ('Poland', 'and', 'Hungary'),
#  ('Robert', 'Redford'),
#  ('Comvik', 'International', 'AB'),
#  ('Rep.', 'Vic', 'Fazio'),
#  ('Dumez',),
#  ('Aussedat', 'Rey', 'S.A.'),
#  ('Kansas',),
#  ('Dreyfus', 'Corp.'),
#  ('W.', 'Herbert', 'Hunt'),
#  ('Westwood', 'Brick', 'Lime', 'Inc.'),
#  ('Bank', 'Building'),
#  ('Peters',),
#  ('Rudolph', 'Wolff', '&', 'Co.'),
#  ('OPEC', 'officials'),
#  ('Robert', 'G.', 'Lee'),
#  ('Daiwa', 'Investment', 'Trust'),
#  ('Calisto', 'Tanzi'),
#  ('U.S.', 'official', 'reserve', 'assets'),
#  ('New', 'Zealand', 'financier', 'Ron', 'Brierley'),
#  ('Management',),
#  ('Power',),
#  ('Guber', 'Peters'),
#  ('Warner', 'and', 'others'),
#  ('Princeton',),
#  ('Jaguar', 'PLC'),
#  ('Health', 'Care', 'Property'),
#  ('Peter', 'Scott'),
#  ('Don', 'Borgeson'),
#  ('Pravda',),
#  ('Stella', 'Artois', 'beers'),
#  ('Lily',),
#  ('Conradies',),
#  ('Mr.', 'Renzas'),
#  ('Release', '1.0'),
#  ('Libor',),
#  ('Kim', 'Schwartz'),
#  ('Nasdaq',),
#  ('Whitbread', '&', 'Co.'),
#  ('President', 'Terry', 'Semel'),
#  ('Personnel',),
#  ('Stamford', 'officials'),
#  ('Mr.', 'Thompson'),
#  ('Banco', 'Popular'),
#  ('Mr.', 'Rothman'),
#  ('Arizona', 'real', 'estate'),
#  ('David', 'A.', 'Wyss'),
#  ('PepsiCo', 'Inc.'),
#  ('Zane', 'Mann'),
#  ('Pacific', 'Daylight', 'Time'),
#  ('Kevin', 'Logan'),
#  ('State', 'Farm', 'Mutual', 'Automobile', 'Insurance', 'Co.'),
#  ('Burrillville',),
#  ('West', 'Germany'),
#  ('Mr.', 'Milunovich'),
#  ('Conning', '&', 'Co.'),
#  ('Texas',
#   ',',
#   'California',
#   ',',
#   'Colorado',
#   ',',
#   'Arizona',
#   'and',
#   'Florida'),
#  ('MMI', 'positions'),
#  ('Oct.', '29', ',', '1929'),
#  ('Dun', '&', 'Bradstreet', 'Corp.'),
#  ('Valley', 'Stream'),
#  ('Sweden',),
#  ('WTXF',),
#  ('Construction', 'Equipment', 'International'),
#  ('Mr.', 'Della', 'Femina'),
#  ('BanPonce', 'Corp.'),
#  ('Fina',),
#  ('Brands',),
#  ('J.M.', 'Cohen'),
#  ('Tom', 'Schumacher'),
#  ('Equitec',),
#  ('Orange',),
#  ('Wall', 'Street', 'estimates'),
#  ('A.G.', 'Edwards', '&', 'Sons', 'Inc.'),
#  ('RD',),
#  ('Chairman', 'Roger', 'W.', 'Johnson'),
#  ('El', 'Al', 'director', 'Rafi', 'Har-Lev'),
#  ('Goldman', ',', 'Sachs', '&', 'Co'),
#  ('Mr.', 'Mitchell', 'Travel', 'Service'),
#  ('Sydney',),
#  ('Briarcliff', 'Manor'),
#  ('Randy', 'Delchamps'),
#  ('Bateman', ',', 'Bryan', '&', 'Galles', 'Inc.'),
#  ('Salomon', 'Brothers', 'Inc'),
#  ('67-year-old', 'Mrs.', 'Thi'),
#  ('Digital', 'Equipment', 'Corp.'),
#  ('Batman',),
#  ('July', '31'),
#  ('Lincoln-Mercury', 'dealerships'),
#  ('JROE',),
#  ('Evelyn', 'Boccone'),
#  ('Salvadoran', 'President', 'Alfredo', 'Cristiani'),
#  ('BellSouth',),
#  ('K-H', 'Corp.'),
#  ('U.S.', 'companies'),
#  ('Monmouth',),
#  ('Germany',),
#  ('Pizza', 'Hut'),
#  ('Rep.', 'James', 'Oberstar'),
#  ('Chase', 'Manhattan', 'Corp.'),
#  ('Fred', 'Oldenburg'),
#  ('Woolworth', 'stores'),
#  ('Merrill', 'Lynch', '&', 'Co'),
#  ('Portfolio', 'B'),
#  ('Business', 'Tokyo', 'magazine'),
#  ('County', 'NatWest', 'Investment', 'Management', 'Ltd.'),
#  ('David', 'S.', 'Black'),
#  ('CONTINENTAL', 'Airlines'),
#  ('Michael', 'Dell'),
#  ('Raytheon', 'Co.'),
#  ('Cornell', 'University'),
#  ('Disney', 'toys'),
#  ('James', 'Daugherty'),
#  ('April', '15', ',', '1999'),
#  ('New', 'York', 'City', 'general', 'obligation', 'bonds'),
#  ('Berkshire', 'Hathaway'),
#  ('Manhattan', 'Life', 'Insurance', 'Co.'),
#  ('Remic', 'issuance'),
#  ('Chrysler', 'Corp.'),
#  ('Union', 'Pacific'),
#  ('Retired', 'couple'),
#  ('UAL', 'employees'),
#  ('Manufacturers',),
#  ('News', 'Corp.'),
#  ('Classic', 'Coke'),
#  ('MeraBank',),
#  ('Affiliated',),
#  ('Missouri',),
#  ('Harry', 'Manion'),
#  ('Yamaichi', 'International'),
#  ('Continental', 'Bank', 'Corp.'),
#  ('Mark', 'Steinkrauss'),
#  ('Los', 'Angeles-based', 'Farmers'),
#  ('NEW', 'ENGLAND', 'CRITICAL', 'CARE', 'Inc.'),
#  ('Toledo',),
#  ('Billie', 'Jean'),
#  ('Arkansas', 'Democrat', 'David', 'Pryor'),
#  ('Harbanse', 'Doman'),
#  ('AC&R', 'Advertising'),
#  ('Senate', 'Majority', 'Leader', 'George', 'Mitchell'),
#  ('Las', 'Vegas'),
#  ('Pharmaceuticals',),
#  ('Representatives',),
#  ('EC', 'inflation'),
#  ('Smith', 'College'),
#  ('Harold', 'W.', 'Smith', 'Sr.'),
#  ('Angel', 'Fire'),
#  ('Columbia', 'University'),
#  ('Mr.', 'Putka'),
#  ('House', 'and', 'Senate', 'negotiators'),
#  ('National', 'Assembly', 'deputies'),
#  ('Mexicana', 'de', 'Aviacion'),
#  ('Mr.', 'Biehl'),
#  ('Geoffrey', 'Goodfellow'),
#  ('President', 'Assad'),
#  ('Canadian', 'Pacific', 'Ltd.'),
#  ('Florida',
#   ',',
#   'Kentucky',
#   ',',
#   'Alabama',
#   ',',
#   'Tennessee',
#   'and',
#   'Louisiana'),
#  ('New', 'York-based', 'Hallwood', 'Group', 'Inc.'),
#  ('Consolidated', 'Rail', 'Corp.'),
#  ('Wall', 'Street', 'analysts'),
#  ('Jack', 'Grubman'),
#  ('Paramount', 'Pictures'),
#  ('Esso',),
#  ('Orin', 'Kramer'),
#  ('Tass',),
#  ('Noriega',),
#  ('Rainer', 'Eppelmann'),
#  ('Noranda', 'and', 'Trelleborg'),
#  ('Dr.', 'Bailit'),
#  ('Singapore',),
#  ('Diamond-Star', 'Motors', 'Corp.'),
#  ('Thomas', 'J.', 'Lipton', 'Co.'),
#  ('Short-term', 'Treasury', 'securities'),
#  ('Calif',),
#  ('American', 'Telephone', '&', 'Telegraph'),
#  ('GOP', 'state', 'Rep.', 'Stephen', 'Freind'),
#  ('FDA', 'approval'),
#  ('School',),
#  ('Guinness',),
#  ('Nov.', '3'),
#  ('Dow', 'Chemical', 'Co.'),
#  ('USA', 'Today'),
#  ('Perth',),
#  ('Addington',),
#  ('Mr.', 'Himebaugh'),
#  ('Ann', 'Adams', 'Webster'),
#  ('Viaje', 'a', 'la', 'Alcarria'),
#  ('Ms.', 'Tilly'),
#  ('Pepperidge', 'Farm'),
#  ('Jack', 'Rivkin'),
#  ('MCA', 'TV'),
#  ('Thomson', 'McKinnon', 'Inc.'),
#  ('Index',),
#  ('Pru-Bache',),
#  ('Sony',),
#  ('First', 'City'),
#  ('David', 'Hockney'),
#  ('Viacom',),
#  ('Nov.', '24', ',', '1994'),
#  ('IBM', 'and', 'MCA'),
#  ('mare-COOR',),
#  ('Mr.', 'Icahn'),
#  ('Florida',),
#  ('First', 'Gibraltar', 'Bank', 'F.S.B.'),
#  ('Marilyn', 'Monroe'),
#  ('Peter', 'J.', 'Canelo'),
#  ('Beefeater', 'gin'),
#  ('Timken',),
#  ('John', 'Markese'),
#  ('Big', 'Board', 'short', 'interest'),
#  ('Arby',),
#  ('Mr.', 'Seidman'),
#  ('Central', 'Bank'),
#  ('Mary', 'Rose', 'Oakar'),
#  ('Richard', 'M.', 'Greenwood'),
#  ('U.S.', 'aid'),
#  ('Samuel', 'James', 'Baker'),
#  ('Richard', 'Webb'),
#  ('Steven', 'B.', 'Enright'),
#  ('Mr.', 'Gourlay'),
#  ('Chase', 'Senior', 'Vice', 'President', 'George', 'Scandalios'),
#  ('Wichita',),
#  ('Merill', 'Lynch', 'International', 'Ltd'),
#  ('International', 'Proteins', 'Corp.'),
#  ('September', 'consumer', 'prices'),
#  ('Chancellor', 'Kohl'),
#  ('Michael', 'Baker'),
#  ('Deutsche', 'Bank', 'AG'),
#  ('May',),
#  ('AEW',),
#  ('Avdel',),
#  ('Eric', 'Philo'),
#  ('Greiner', 'Engineering'),
#  ('Io',),
#  ('Jan.', '28', ',', '1990'),
#  ('Capital', 'Supervisors', 'Inc.'),
#  ('Infotechnology', 'Inc.'),
#  ('Mr.', 'Schwartz'),
#  ('Trelleborg', 'and', 'Noranda'),
#  ('James', 'Baker'),
#  ('General', 'Electric', 'Co.'),
#  ('Byelorussia',),
#  ('California', 'state', 'and', 'local', 'municipal', 'debt'),
#  ('GE', 'technology'),
#  ('Atlanta',),
#  ('Federal', 'Reserve', 'banks', 'or', 'branches'),
#  ('Imasco',),
#  ('Income',),
#  ('Palo', 'Alto'),
#  ('Cupertino',),
#  ('Kinney', 'and', 'Foot', 'Locker', 'shoe', 'stores'),
#  ('Inland',),
#  ('Apple',
#   'Computer',
#   'Inc.',
#   'or',
#   'International',
#   'Business',
#   'Machines',
#   'Corp.',
#   'hardware'),
#  ('Westpac', 'Banking', 'Corp'),
#  ('N.M.',),
#  ('Refcorp',),
#  ('Connaught',),
#  ('Big', 'Board', 'volume'),
#  ('Tillinghast',),
#  ('Equitec', 'Chairman', 'Richard', 'L.', 'Saalfeld'),
#  ('European', 'Investment', 'Bank'),
#  ('Robert', 'Delaney'),
#  ('Apple',),
#  ('John', 'Morton'),
#  ('Sekisui', 'House'),
#  ('Grupo', 'Desc'),
#  ('Hepatitis', 'A'),
#  ('Capcom', 'Financial'),
#  ('Boris', '`', 'Bo', "'", 'Regaard'),
#  ('Merrill',),
#  ('business',),
#  ('Nevada',),
#  ('Scorpios',),
#  ('Bank', 'Bumiputra'),
#  ('King', 'Broadcasting', 'Co.'),
#  ('National', 'Steel', 'Corp'),
#  ('Sen.', 'Orrin', 'Hatch'),
#  ('Pa',),
#  ('B.A.T', 'Industries'),
#  ('Tandem', 'Computers', 'Inc.'),
#  ('February',),
#  ('DGAULT',),
#  ('Mr.', 'Mastro'),
#  ('Prudential-Bache', 'Capital', 'Funding'),
#  ('Richmond', ',', 'Va.-based', 'Universal', 'Corp.'),
#  ('LIN', 'Broadcasting', 'Corp.'),
#  ('R.I.',),
#  ('Better', 'Business', 'Bureaus'),
#  ('Greenwich',),
#  ('Walter', 'Yetnikoff'),
#  ('Gordon',),
#  ('Mark',),
#  ('Bass', 'PLC'),
#  ('Poodle',),
#  ('Saks', 'Fifth', 'Avenue'),
#  ('Societe', 'Commerciale'),
#  ('H&R', 'Block', 'tax', 'services'),
#  ('Southwestern', 'Bell', 'Telephone', 'Co.'),
#  ('IATA',),
#  ('Voyager',),
#  ('Armco', 'Inc.'),
#  ('Nov.', '8'),
#  ('Acton',),
#  ('Anterior', 'Technology'),
#  ('Pinpoint', 'Information', 'Corp.'),
#  ('Chevrolet',),
#  ('Automated', 'teller', 'machine', 'operations'),
#  ('Kraft', 'General', 'Foods'),
#  ('Candlestick', 'Park'),
#  ('Money',),
#  ('Chongju',),
#  ('Michael', 'W.', "O'Donnell"),
#  ('West', 'Texas', 'Intermediate'),
#  ('First', 'Fidelity'),
#  ('Aberdeen', 'Group', 'Inc'),
#  ('Lone', 'Star', 'Beer'),
#  ('Chemical', 'Waste', 'Management'),
#  ('Independents',),
#  ('Texas', 'Instruments'),
#  ('Friday', 'afternoon'),
#  ('Travis', 'Air', 'Force', 'Base'),
#  ('Total', 'Merkur', 'sales'),
#  ('Cormack', 'Enterprises', 'Inc.'),
#  ('Coastal', 'Corp.'),
#  ('Amex',),
#  ('International', 'Business', 'Machines', 'Corp.', 'computers'),
#  ('Texas', 'pride'),
#  ('October', '1982'),
#  ('Berkshire', 'Hathaway', 'Inc.'),
#  ('Paul', 'P.', 'Aniskovich', 'Jr.'),
#  ('Housing', 'and', 'Urban', 'Development'),
#  ('John', 'Sculley'),
#  ('SciMed', 'shares'),
#  ('J.P.', 'Morgan', 'Securities', 'Inc.'),
#  ('Series', 'trivia'),
#  ('Lake', 'Charles'),
#  ('British', 'Aerospace', 'PLC'),
#  ('Colgate', 'toothpaste'),
#  ('U.S.', 'history'),
#  ('Dec.', '1', ',', '1989'),
#  ('First', 'Iberian', 'Fund'),
#  ('Bernard', 'Savaiko'),
#  ('Michelle', 'Van', 'Cleave'),
#  ('Tax', 'Preparation'),
#  ('Maury', 'Elvekrog'),
#  ('Harley',),
#  ('Surety', 'Savings', 'Association'),
#  ('Sony', 'Corp.'),
#  ('Mr.', 'Trump'),
#  ('April', '4', ',', '1988'),
#  ('Empire-Berol',),
#  ('Sigma', 'Financial', 'Inc.'),
#  ('Mary', 'Spaulding'),
#  ('Beefeater',),
#  ('CSC',),
#  ('Schlumberger', 'Ltd.'),
#  ('Colorado', 'Springs'),
#  ('KTXL',),
#  ('W.', 'Mark', 'Goode'),
#  ('Mr.', 'Diebel'),
#  ('Alexandra', 'Armstrong', 'Advisors', 'Inc.'),
#  ('Compaq', 'Computer', 'Corp.'),
#  ('NRC', 'policy'),
#  ('Morrison', 'Knudsen'),
#  ('Congress',),
#  ('Financial', 'Affairs', 'Inc.'),
#  ('Singapore', 'and', 'Tokyo'),
#  ('Humana',),
#  ('London-based', 'WCRS'),
#  ('Winnebago',),
#  ('Quantum',),
#  ('Dr.', 'Frank', 'Provato'),
#  ('Teresa', 'de', 'Cepeda'),
#  ('Bernie', 'Ohls'),
#  ('Harry', 'B.', 'Helmsley'),
#  ('Ferdinand', 'Marcos'),
#  ('Norman', 'Abramson'),
#  ('U.S.', 'takeover-stock', 'speculators'),
#  ('Bethlehem', 'Steel', 'Corp.'),
#  ('U.S.', 'firms'),
#  ('Merck',),
#  ('South', 'Jersey'),
#  ('Safeco', 'Title', 'Insurance', 'Co.'),
#  ('U.S.', 'contributions'),
#  ('Hartford',),
#  ('Edward', 'J.', 'Tirello', 'Jr.'),
#  ('Finance',),
#  ('Nassau-Suffolk',),
#  ('Carnival', 'Cruise', 'Lines', 'Class', 'A'),
#  ('Santa', 'Fe', 'Pacific', 'Corp.'),
#  ('Noxell', 'common', 'and', 'Class', 'B', 'stock'),
#  ('A.P.', 'Green'),
#  ('Senate', 'Democrats'),
#  ('Mr.', 'Ross'),
#  ('Vista', 'Chemical', 'Co.'),
#  ('Rhode', 'Island'),
#  ('Sutro',),
#  ('Alan', 'Weston'),
#  ('USAir', 'Group'),
#  ('Vickers',),
#  ('Fla.',),
#  ('Texas', 'A&M'),
#  ('Barbie', 'doll'),
#  ('April', '6', ',', '1973'),
#  ('American', 'International', 'Group', 'Inc.'),
#  ('U.S.', 'operatives'),
#  ('Mr.', 'Sculley'),
#  ('Bristol',),
#  ('Thomas', 'M.', 'Bloch'),
#  ('Glen', 'Halva-Neubauer'),
#  ('International', 'Proteins', 'shares'),
#  ('New', 'York', 'Co.'),
#  ('July',),
#  ('Treasury', 'notes'),
#  ('Paribas', 'and', 'Lonrho'),
#  ('El', 'Espectador', 'journalists', 'and', 'staff'),
#  ('Thursday',),
#  ('Bob', 'Machon'),
#  ('Federal', 'Express', 'Corp.'),
#  ('AC&R', 'ADVERTISING'),
#  ('Johannesburg',),
#  ('Mr.', 'Sherlund'),
#  ('NatWest', 'and', 'Merrill'),
#  ('Capital', 'Cities-ABC'),
#  ('Morgan', 'Stanley', 'Capital', 'International', 'Perspective'),
#  ('Mr.', 'Markese'),
#  ('Trustcorp', 'Inc.'),
#  ('Ajinomoto',),
#  ('Health', 'and', 'Human', 'Services'),
#  ('Chevy', 'trucks'),
#  ('Streetspeak',),
#  ('Rutgers', 'University'),
#  ('Peter', 'G.', 'Diamandis'),
#  ('MacNamara', 'Clapp', '&', 'Klein'),
#  ('Oklahoma', 'official', 'Robert', 'Fulton'),
#  ('Tandy',),
#  ('Evans', 'Inc.'),
#  ('El', 'Al'),
#  ('Gov.', 'Kean'),
#  ('SNET', 'chairman', 'and', 'chief', 'executive', 'officer'),
#  ('Treasury', 'bills'),
#  ('Portland',),
#  ('Montgomery', 'Securities', 'Inc.'),
#  ('Iran',),
#  ('Guber',),
#  ('Pearl', 'Group'),
#  ('Olivetti', 'USA'),
#  ('Northrop',),
#  ('PPI',),
#  ('Clue',),
#  ('Mayor', 'Agnos'),
#  ('USAir',),
#  ('Fox', 'Broadcasting'),
#  ('Ho', 'Chi', 'Minh', 'City', 'party', 'secretary'),
#  ('Clinton', 'Gas', 'Systems', 'Inc.'),
#  ('Legal', '&', 'General'),
#  ('Steinhardt', 'Partners'),
#  ('Hanson', 'PLC'),
#  ('March', '31', ',', '1994'),
#  ('Delaware', 'Chancery', 'Court'),
#  ('Fridays',),
#  ('Baring', 'Brothers', '&', 'Co.'),
#  ('Newport',),
#  ('Nov.', '22'),
#  ('Alan', 'G.', 'Hassenfeld'),
#  ('Pinnacle', 'West', 'Capital', 'Corp.'),
#  ('Credit', 'Suisse', 'First', 'Boston', 'Ltd'),
#  ('Ameron',),
#  ('Prudential', 'Insurance', 'Co.'),
#  ('NASA',),
#  ('Susie', 'Diamond'),
#  ('Harrisburg',),
#  ('Fulton', 'Prebon'),
#  ('Bronson', ',', 'Bronson', '&', 'McKinnon'),
#  ('Los', 'Gatos'),
#  ('Irvine', 'Co.'),
#  ('April', '27'),
#  ('Hill', 'Street', 'Blues'),
#  ('Robert', 'W.', 'Kasten'),
#  ('Atchinson', 'County'),
#  ('Keizaikai',),
#  ('Bankers', 'Trust', 'Co'),
#  ('August', '1988'),
#  ('Robert', 'M.', 'White'),
#  ('Edward', 'J.', 'Campbell'),
#  ('Md',),
#  ('PaineWebber', 'Group', 'Inc.'),
#  ('Prof.', 'James', 'Tobin'),
#  ('Lai', 'Nguyen', 'An'),
#  ('FT-SE', '100', 'shares'),
#  ('Mr.', 'Parker'),
#  ('Minpeco', 'S.A.'),
#  ('United', 'Airlines', 'parent', 'UAL', 'Corp.'),
#  ('December', 'delivery', 'gold'),
#  ('NCNB', 'Corp.'),
#  ('Sacremento',),
#  ('Silicon', 'Valley'),
#  ('Terry', 'Pryce'),
#  ('Corroon', '&', 'Black'),
#  ('Spokane',),
#  ('Erdos', '&', 'Morgan', 'Inc.'),
#  ('Kate', 'Michelman'),
#  ('Khmer', 'Rouge', 'camps'),
#  ('Series', '1989'),
#  ('Loral',),
#  ('Saturday', 'night'),
#  ('Promotion',),
#  ('Fremont',),
#  ('WCRS', 'and', 'Eurocom'),
#  ('MC', 'SHIPPING', 'Inc.'),
#  ('John', 'Rohs'),
#  ('Raymond', 'Chandler'),
#  ('Bob', 'Barber'),
#  ('Keihin', 'Electric', 'Express', 'Railway', 'Co'),
#  ('Reggie', 'Jackson'),
#  ('Mr.', 'Corcoran'),
#  ('Bear', ',', 'Stearns'),
#  ('Mr.', 'Oriani'),
#  ('Hugo', 'Quackenbush'),
#  ('Oct',),
#  ('Federal', 'and', 'state', 'tax', 'enforcers'),
#  ('Shearson', 'Lehman', 'Hutton', 'Holdings', 'Inc.'),
#  ('WSJ', 'Oct.', '20', ',', '1989'),
#  ('Sotheby',),
#  ('Ontario',),
#  ('James', 'F.', 'Gero'),
#  ('Adsi', 'Inc.'),
#  ('Day', 'orders'),
#  ('Coal', 'prices'),
#  ('Mr.', 'Peterson'),
#  ('Oct.', '13'),
#  ('Chile', ',', 'Cuba', ',', 'Panama', 'or', 'Haiti'),
#  ('Massachusetts', 'Attorney', 'General', 'James', 'Shannon'),
#  ('Clinton',),
#  ('Pieter', 'Bruwer'),
#  ('Charles', 'Lieberman'),
#  ('Fuji', 'technology'),
#  ('Tandem', 'Computers'),
#  ('Peter', 'Isler'),
#  ('Control', 'Data', 'Corp'),
#  ('Papa',),
#  ('Bay', 'area', 'clients'),
#  ('Ms.', 'Levine'),
#  ('PPG',),
#  ('Irving',),
#  ('Analyst', 'James', 'Weil'),
#  ('American', 'Express', 'Information', 'Services'),
#  ('La', 'Familia', 'de', 'Hoy'),
#  ('Stop-Limit', 'Order'),
#  ('Emeryville',),
#  ('Land',),
#  ('Sally', 'Stewart'),
#  ('Mr.', 'Bush'),
#  ('Federal', 'Highway', 'Administrator', 'Thomas', 'Larson'),
#  ('London', 'brokers', 'County', 'NatWest', 'WoodMac'),
#  ('London', 'bullion', 'brokers'),
#  ('Frank', 'Salerno'),
#  ('Lewis', 'Galoob', 'Toys'),
#  ('Deloitte', ',', 'Haskins', '&', 'Sells', 'International'),
#  ('Nixon', ',', 'Hargrave', ',', 'Devans', '&', 'Doyle'),
#  ('Overnite', 'Transportation', 'earnings'),
#  ('Dec.', '15'),
#  ('William', 'Seidman'),
#  ('Commons',),
#  ('Southdown',),
#  ('Romania',),
#  ('Tan', 'Sri', 'Basir'),
#  ('January', '1989'),
#  ('California',),
#  ('Mellon', 'Bank', 'Corp.'),
#  ('Polygram', 'Pictures'),
#  ('Mayor', 'Carolyn', 'Robinson'),
#  ('Suggestion', 'Systems'),
#  ('Mr.', 'Breene'),
#  ('David', 'M.', 'Carroll'),
#  ('Harvard',),
#  ('February', '1987'),
#  ('Peter', 'Jarvis'),
#  ('Torrence', 'Johnson'),
#  ('Mattel', 'Inc.'),
#  ('Cipher', 'Data', 'Products', 'Inc.'),
#  ('BankAmerica',),
#  ('Triad',),
#  ('Bell', 'Atlantic'),
#  ('Paramount', 'Domestic', 'TV'),
#  ('Professor',),
#  ('CalFed',),
#  ('Mass',),
#  ('Ms.', 'Masaki-Schatz'),
#  ('Fed', 'credit', 'policy', 'changes'),
#  ('Jamie', 'Kellner'),
#  ('Bozell', 'Inc.'),
#  ('Resolution', 'Trust', 'Corp.'),
#  ('Farmers',),
#  ('Peter', 'S.', 'Willmott'),
#  ('Sept.', '20'),
#  ('New', 'Jersey', 'Turnpike', 'Authority'),
#  ('Mr.', 'Jackson', "'s"),
#  ('Timken', 'Co.'),
#  ('Candlestick',),
#  ('Hendrik', 'F.', 'Verwoerd'),
#  ('Aetna', 'Life', '&', 'Casualty', 'Insurance', 'Co.'),
#  ('Marx',),
#  ('General', 'Motors', 'Corp.'),
#  ('Mr.', 'Greenberg'),
#  ('Louisville',),
#  ('Merrill', 'Lynch'),
#  ('Miss.',),
#  ('State', ',', 'Justice', 'and', 'Commerce'),
#  ('Mark', 'Cremonie'),
#  ('Sanford', 'C.', 'Bernstein', '&', 'Co.'),
#  ('J.P.', 'Morgan', '&', 'Co.'),
#  ('Western', 'Europe'),
#  ('HUD', 'officials'),
#  ('Turnaround', 'Letter'),
#  ('Mr.', 'Delchamps'),
#  ('Valley', 'National'),
#  ('Himont',),
#  ('DDB', 'Needham'),
#  ('FileNet',),
#  ('Inmac',),
#  ('McDonald',),
#  ('Mobile', 'Communications', 'Corp.'),
#  ('Wednesday', 'or', 'Thursday'),
#  ('First', 'Fidelity', 'Bancorp.'),
#  ('Vice', 'President', 'Dan', 'Quayle'),
#  ('AMR',),
#  ('Duff', '&', 'Phelps', 'Inc'),
#  ('NORTHERN', 'CALIFORNIA'),
#  ('Dow', 'Jones', 'Professional', 'Investor', 'Report'),
#  ('Winter', 'Carnival', 'week'),
#  ('Aetna',),
#  ('Martin', 'J.', '``', 'Hoot', "''", 'McInerney'),
#  ('Frederick', 'Smith'),
#  ('Industrial', 'output'),
#  ('MMS', 'International'),
#  ('DILLARD', 'DEPARTMENT', 'STORES', 'Inc.'),
#  ('October',),
#  ('Allstate', 'Insurance', 'Co.'),
#  ('Jerry', 'Lackey'),
#  ('Guber', 'Peters', 'pictures'),
#  ('Kansas', 'and', 'Texas'),
#  ('Ltd',),
#  ('Ala.',),
#  ('Idaho',),
#  ('Sirota', ',', 'Alper', '&', 'Pfau'),
#  ('Atlantis',),
#  ('Mr.', 'Hicks'),
#  ('American', 'Express', 'Information', 'Services', 'Co'),
#  ('Royal', 'Dutch\\/Shell', 'Group'),
#  ('Cineplex',),
#  ('STOCK', 'MARKET', 'PATOIS'),
#  ('Saturdays', ',', 'Sundays', 'and', 'Mondays'),
#  ('Pemex', 'managers'),
#  ('Dec.', '29', ',', '1988'),
#  ('Marshall', 'Coleman'),
#  ('Ms.', 'Bettner'),
#  ('Fidelity',),
#  ('Bank', 'Julius', 'Baer'),
#  ('Hunt', 'Valley'),
#  ('Value', 'Matrix', 'Management', 'Inc.'),
#  ('Harris', 'Amhowitz'),
#  ('Sam', 'Whitbread'),
#  ('Oct.', '17'),
#  ('Christmas',),
#  ('LifeSpan', 'Inc.'),
#  ('Oct.', '19', ',', '1987'),
#  ('CD',),
#  ('GTE', 'officials'),
#  ('Fernando', 'Volio'),
#  ('Mr.', 'McClelland'),
#  ('Schering-Plough', 'Health', 'Care', 'Products'),
#  ('Citicorp', 'and', 'Chase'),
#  ('Silver', 'Spring'),
#  ('UAL', 'shares'),
#  ('Lowell',),
#  ('Kidder', 'Peabody'),
#  ('Chernobyl',),
#  ('Republican', 'freeholders'),
#  ('Eddie', 'Mahe'),
#  ('San', 'Jose'),
#  ('Metropolitan', 'Life', 'Insurance', 'Co.'),
#  ('Louisiana', 'officials'),
#  ('Heberto', 'Castillo'),
#  ('UAL', 'flight', 'attendants'),
#  ('Crest',),
#  ('Paul', 'Fireman'),
#  ('Hilton',),
#  ('Mr.', 'Gras'),
#  ('Winter', 'Haven'),
#  ('Navin', 'Vyas'),
#  ('Ameritech', 'Corp.'),
#  ('N.J.',),
#  ('Banc', 'One', 'Corp.'),
#  ('NATO',),
#  ('Ben', 'Hanauer'),
#  ('Union', 'Pacific', 'Corp.'),
#  ('Amex', 'short', 'interest'),
#  ('Honduras',),
#  ('Robert', 'Lekberg'),
#  ('Garden', 'City'),
#  ('International', 'Forest', 'Products', 'Ltd.'),
#  ('Enserch', 'Corp.'),
#  ('Carriers',),
#  ('Martin', 'Fleischmann'),
#  ('Dec.', '30'),
#  ('Mr.', 'Keith'),
#  ('Georgia-Pacific', 'stock'),
#  ('Fannie', 'Mae', '9', '%', 'securities'),
#  ('Providence',),
#  ('Commerce',),
#  ('KIM',),
#  ('Walter', 'H.', 'Monteith', 'Jr.'),
#  ('Anton', 'Amon'),
#  ('Standard', '&', 'Poor'),
#  ('International', 'Business', 'Machines', 'Corp'),
#  ('Chairman', 'Richard', 'M.', 'Morrow'),
#  ('Sandinista', 'propaganda'),
#  ('Casablanca', 'Records', 'and', 'Filmworks'),
#  ('Varity', 'Corp.'),
#  ('Jacob', 'Dreyer'),
#  ('Cotton', 'Daly'),
#  ('Shearson', 'shares'),
#  ('Santa', 'Cruz', 'County'),
#  ('Sperry', 'Corp'),
#  ('New', 'York'),
#  ('Christopher', 'Whittington'),
#  ('Ragu', 'spaghetti', 'sauce'),
#  ('Stacy', 'Kotman'),
#  ('East', 'Rock', 'Partners', 'L.P'),
#  ('Aqua', 'Net', 'hairspray'),
#  ('Teamsters',),
#  ('Ms.', 'Tharp'),
#  ('Polycast', 'Technology', 'Corp'),
#  ('Gen.', 'Manuel', 'Noriega'),
#  ('Reuben', 'Mark'),
#  ('Deloitte', 'and', 'Touche', 'world-wide'),
#  ('SH', 'Oil'),
#  ('Agricola',),
#  ('January',),
#  ('Moscow',),
#  ('House', 'Speaker', 'James', 'Wright'),
#  ('Della', 'Femina', 'McNamee'),
#  ('Nguyen', 'Van', 'Chan'),
#  ('Ignazio', 'J.', 'Ruvolo'),
#  ('Governors',),
#  ('Block',),
#  ('NYSE',),
#  ('Avianca',),
#  ('St.', 'Johns', 'River', 'Water', 'Management', 'District'),
#  ('Webster', 'Financial', 'Corp.'),
#  ('DOE',),
#  ('OPEC',),
#  ('AT&T', 'shares'),
#  ('Dell', 'Computer'),
#  ('Individual', 'Inc.'),
#  ('Palms',),
#  ('Craig', 'O.', 'McCaw'),
#  ('Northern', 'California', 'home', 'prices'),
#  ('Europeans',),
#  ('Mr.', 'Smalling'),
#  ('Englewood',),
#  ('John', 'Gargan'),
#  ('House', 'Appropriations', 'Committee', 'Chairman', 'Jamie', 'Whitten'),
#  ('Investigation',),
#  ('Beauregard',),
#  ('Mr.', 'Vyas'),
#  ('Norton', 'and', 'GE'),
#  ('Granges',),
#  ('Series', '105'),
#  ('Northern', 'California'),
#  ('Saab',),
#  ('Cowan', '&', 'Owen'),
#  ('Carter', 'Hawley', 'Hale', 'Stores', 'Inc.'),
#  ('Stokely',),
#  ('Hustead',),
#  ('Wednesday', 'morning'),
#  ('Millicom', 'Inc.'),
#  ('Seagate',),
#  ('Chicago', 'federal', 'court'),
#  ('John', 'S.', 'Reidy'),
#  ('County', 'NatWest', 'Ltd.'),
#  ('East', 'Germans'),
#  ('Prudential-Bache', 'Securities', 'Inc.'),
#  ('SAMURAI',),
#  ('Peter',),
#  ('Lloyd', 'Bentsen'),
#  ('Multiflow', 'Computer', 'Inc.'),
#  ('Cathay', 'Pacific', 'Airways'),
#  ('August', '30'),
#  ('Peter', 'Appert'),
#  ('John', 'Hancock', 'Freedom', 'Securities'),
#  ('Senator', 'John', 'Kerry'),
#  ('International', 'Business', 'Machines', 'Corp.'),
#  ('Maury', 'Kelley'),
#  ('Tokyo', 'market', 'participants'),
#  ('Judge', 'Louis', 'L.', 'Stanton'),
#  ('Pemex',),
#  ('Betty', 'Lombardi'),
#  ('Bear', ',', 'Stearns', '&', 'Co'),
#  ('America',),
#  ('Rwanda',),
#  ('Ms.', 'Smith'),
#  ('T.', 'Rowe', 'Price', 'mutual-fund', 'groups'),
#  ('Renault',),
#  ('Rep.', 'Stephen', 'Neal'),
#  ('Syria', ',', 'Iran', 'and', 'Iraq'),
#  ('Minpeco', 'attorney', 'Thomas', 'Gorman'),
#  ('Supplemental', 'Security', 'Income', 'payments'),
#  ('Miller', 'Brewing', 'Co.'),
#  ('Trinova', 'third-quarter', 'loss'),
#  ('Jeffrey', 'B.', 'Lane'),
#  ('Mr.', 'Garcia'),
#  ('Trans', 'World', 'Airlines'),
#  ('Time',),
#  ('Marshall', 'Field'),
#  ('Valley', 'National', 'Corp.'),
#  ('Ariz',),
#  ('Ford', 'and', 'Saab'),
#  ('Leo', 'J.', 'Shapiro', '&', 'Associates'),
#  ('S.C',),
#  ('Mansion', 'House'),
#  ('Prudential-Bache',),
#  ('Newport', 'News'),
#  ('Harold', 'Hershhenson'),
#  ('Walt', 'Disney', 'Co.'),
#  ('Old', 'network', 'hands'),
#  ('New',
#   'York',
#   'Times',
#   'Co.',
#   'chairman',
#   'and',
#   'chief',
#   'executive',
#   'officer'),
#  ('General', 'Cinema', 'Corp.'),
#  ('Location', 'Management'),
#  ('Midnight', 'Express'),
#  ('Barclays', 'de', 'Zoete', 'Wedd'),
#  ('Compaq', 'Computer'),
#  ('Kean', 'forces'),
#  ('Sapporo',),
#  ('Bavaria', 'and', 'Baden-Wuerttemberg'),
#  ('Cleveland',),
#  ('Ticor', 'Title', 'Insurance', 'Co.'),
#  ('Mrs.', 'Sutcliffe'),
#  ('First', 'Bank', 'System'),
#  ('Stewart', 'Gilchrist'),
#  ('National', 'Advanced', 'Systems'),
#  ('Fiat', 'S.p', '.', 'A.'),
#  ('Mr.', 'Luthringshausen'),
#  ('Los', 'Angeles-based', 'H.F.', 'Ahmanson'),
#  ('RJR', 'Nabisco', 'Inc.'),
#  ('Grace', 'Energy'),
#  ('William', 'Sullivan', 'Jr.'),
#  ('Sen.', 'John', 'Kerry'),
#  ('Clifford', 'Sayre'),
#  ('Chevy',),
#  ('Alex', 'Kroll'),
#  ('International', 'Data', 'Corp.'),
#  ('Chez', 'Panisse'),
#  ('Wisconsin',),
#  ('New',
#   'York',
#   'consulting',
#   'firm',
#   'Simat',
#   ',',
#   'Helliesen',
#   '&',
#   'Eichner',
#   'Inc'),
#  ('Morrison', 'Knudsen', 'Corp.'),
#  ('HOLLYWOOD', 'Inc.'),
#  ('Fort', 'Lauderdale'),
#  ('Stanley', 'Rose'),
#  ('Security', 'Pacific', 'Corp.'),
#  ('Antique', 'Dealers'),
#  ('Stinson', 'Beach'),
#  ('Champion',),
#  ('Kollmorgen',),
#  ('Afrikanerdom',),
#  ('Burton', 'Lee'),
#  ('Sibra', 'Products', 'Inc.'),
#  ('San', 'Francisco-based', 'Pacific', 'Telesis'),
#  ('U.S.', 'intelligence'),
#  ('Royal', 'Insurance'),
#  ('Takanori', 'Mizuno'),
#  ('Cessna',),
#  ('Western', 'Digital'),
#  ('Commodore', 'International'),
#  ('Ky',),
#  ('San', 'Francisco', 'area', 'officials'),
#  ('Mr.', 'Sugarman'),
#  ('Assistant', 'U.S.', 'Attorney', 'Terry', 'Hart'),
#  ('Sen.', 'Mitchell'),
#  ('Dean', 'Witter'),
#  ('Douglas', 'B.', 'Evans'),
#  ('National', 'Health', 'Care', 'Affiliates', 'Inc.'),
#  ('November', 'delivery'),
#  ('Ford', 'Motor', 'Co.'),
#  ('South', 'Carolina'),
#  ('Capital', 'Holding'),
#  ('Tokyo',),
#  ('T.', 'Rowe', 'Price'),
#  ('Abortion',),
#  ('Sam', 'Ginn'),
#  ('Healthcare',),
#  ('Paramount', 'Chairman', 'Martin', 'Davis'),
#  ('Grand', 'Union', 'Co.'),
#  ('Mr.', 'Maynard'),
#  ('Kurds',),
#  ('Scottish', 'Amicable'),
#  ('Bonwit',
#   'Teller',
#   'and',
#   'B.',
#   'Altman',
#   'parent',
#   'L.J.',
#   'Hooker',
#   'Corp.'),
#  ('Haskins', '&', 'Sells'),
#  ('Highland', 'Valley'),
#  ('Nov.', '14'),
#  ('Steven', 'G.', 'Einhorn'),
#  ('Frederick', 'G.', 'Hicks'),
#  ('Egon', 'Krenz'),
#  ('Michael', 'Simmons'),
#  ('Foreign', 'Minister', 'Hans-Dietrich', 'Genscher'),
#  ('H&R', 'Block', 'stock'),
#  ('Norfolk',),
#  ('Long', 'Island'),
#  ('Tegucigalpa',),
#  ('American', 'Medical'),
#  ('Alfred', 'Goldman'),
#  ('Pasquale', 'Pignatelli'),
#  ('Trinova',),
#  ('Becton', ',', 'Dickinson', '&', 'Co.'),
#  ('Messrs.', 'Fleischmann', 'and', 'Pons'),
#  ('New', 'Yorkers'),
#  ('Sunday', 'River'),
#  ('El', 'Monte'),
#  ('July', '11', ',', '1988'),
#  ('Philippe', 'Gras'),
#  ('United', 'Egg', 'Producers'),
#  ('St.', 'Petersburg'),
#  ('John', 'C.', 'Burton'),
#  ('Heineken',),
#  ('TransAtlantic', 'Holdings', 'PLC'),
#  ('Chemical', 'Securities', 'Inc.'),
#  ('Joan', 'Tharp'),
#  ('NBC',),
#  ('Georgia-Pacific', 'Corp.'),
#  ('United', 'Airlines', 'parent'),
#  ('Anglo-Dutch', 'Unilever', 'Group'),
#  ('Democratic', 'Gov.', 'James', 'Blanchard'),
#  ('Douglas', 'Watson'),
#  ('HUD', 'loans'),
#  ('East', 'Germany'),
#  ('Soo', 'Line', 'shares'),
#  ('maitre', "'d"),
#  ('Mr.', 'Whitten'),
#  ('U.S.', 'government', 'bonds'),
#  ('Merkur', 'prices'),
#  ('Warren', 'E.', 'Buffett'),
#  ('Consultant', 'John', 'Keller'),
#  ('Chrysler', 'officials'),
#  ('Sports',),
#  ('Kary', 'Moss'),
#  ('Lockheed', 'Corp.'),
#  ('Irvine',),
#  ...]

# %%
len(ne_set)
# Out:
# 4348

# %%
len(ne_set)
# Out:
# 4348

# %%
list(ne_set)[:10]
# Out:
# [('Republican-governor\\/Democratic-legislature', 'lines'),
#  ('Alfred', 'Hayes'),
#  ('Cindy', 'Katz'),
#  ('Data', 'General', 'Corp.'),
#  ('Imperial', 'Cup', 'Corp.'),
#  ('British', 'Air', 'shareholders'),
#  ('Robert', 'Cawthorn'),
#  ('Honeywell',),
#  ('Reuters',),
#  ('Mr.', 'Bennett')]

# %%
ne_set
# Out:
# {('Republican-governor\\/Democratic-legislature', 'lines'),
#  ('Alfred', 'Hayes'),
#  ('Cindy', 'Katz'),
#  ('Data', 'General', 'Corp.'),
#  ('Imperial', 'Cup', 'Corp.'),
#  ('British', 'Air', 'shareholders'),
#  ('Robert', 'Cawthorn'),
#  ('Honeywell',),
#  ('Reuters',),
#  ('Mr.', 'Bennett'),
#  ('Chantilly',),
#  ('IMS', 'International'),
#  ('Nac', 'Re', 'Corp.'),
#  ('Prudential', 'Home', 'Mortgage', 'Co.'),
#  ('Pride', 'Petroleum', 'Services', 'Inc.'),
#  ('Aruba',),
#  ('U.S.', 'productivity'),
#  ('AT&T', 'managers'),
#  ('Lipton', 'iced', 'tea'),
#  ('San', 'Juan'),
#  ('Central', 'America'),
#  ('Wacoal', 'Corp.'),
#  ('Money', 'Market', 'Deposits'),
#  ('I.E.P.', 'Securities', 'Ltd.'),
#  ('Saatchi', '&', 'Saatchi', 'Co'),
#  ('George', 'Orwell'),
#  ('Arthur', 'D.', 'Little', 'Inc.'),
#  ('Nov.', '29'),
#  ('Gold', 'and', 'silver', 'broker', 'Preston', 'Semel'),
#  ('USACafes', 'Limited', 'Partnership'),
#  ('Government', 'National', 'Mortgage', 'Association', '9', '%', 'securities'),
#  ('PRINCE', 'HENRI'),
#  ('Prestige', 'U.'),
#  ('Grant',),
#  ('Buffalo',),
#  ('Dreyfus',),
#  ('Southern', 'California'),
#  ('Mr.', 'Byrne'),
#  ('Newark',),
#  ('James', 'Smith'),
#  ('Mr.', 'and', 'Mrs.', 'Peter', 'S.', 'Rubin'),
#  ('Francis', 'Dang'),
#  ('Great', 'Western', 'Financial'),
#  ('National', 'Westminister'),
#  ('Moslems', 'and', 'Christians'),
#  ('NV', 'DSM'),
#  ('Jeff', 'and', 'Beau'),
#  ('Aetna', 'Life', '&', 'Casualty'),
#  ('General', 'Motors'),
#  ('Autodesk',),
#  ('Jan.', '1'),
#  ('Public', 'Service', 'Co.'),
#  ('Sciences',),
#  ('Poland', 'and', 'Hungary'),
#  ('Robert', 'Redford'),
#  ('Comvik', 'International', 'AB'),
#  ('Rep.', 'Vic', 'Fazio'),
#  ('Dumez',),
#  ('Aussedat', 'Rey', 'S.A.'),
#  ('Kansas',),
#  ('Dreyfus', 'Corp.'),
#  ('W.', 'Herbert', 'Hunt'),
#  ('Westwood', 'Brick', 'Lime', 'Inc.'),
#  ('Bank', 'Building'),
#  ('Peters',),
#  ('Rudolph', 'Wolff', '&', 'Co.'),
#  ('OPEC', 'officials'),
#  ('Robert', 'G.', 'Lee'),
#  ('Daiwa', 'Investment', 'Trust'),
#  ('Calisto', 'Tanzi'),
#  ('U.S.', 'official', 'reserve', 'assets'),
#  ('New', 'Zealand', 'financier', 'Ron', 'Brierley'),
#  ('Management',),
#  ('Power',),
#  ('Guber', 'Peters'),
#  ('Warner', 'and', 'others'),
#  ('Princeton',),
#  ('Jaguar', 'PLC'),
#  ('Health', 'Care', 'Property'),
#  ('Peter', 'Scott'),
#  ('Don', 'Borgeson'),
#  ('Pravda',),
#  ('Stella', 'Artois', 'beers'),
#  ('Lily',),
#  ('Conradies',),
#  ('Mr.', 'Renzas'),
#  ('Release', '1.0'),
#  ('Libor',),
#  ('Kim', 'Schwartz'),
#  ('Nasdaq',),
#  ('Whitbread', '&', 'Co.'),
#  ('President', 'Terry', 'Semel'),
#  ('Personnel',),
#  ('Stamford', 'officials'),
#  ('Mr.', 'Thompson'),
#  ('Banco', 'Popular'),
#  ('Mr.', 'Rothman'),
#  ('Arizona', 'real', 'estate'),
#  ('David', 'A.', 'Wyss'),
#  ('PepsiCo', 'Inc.'),
#  ('Zane', 'Mann'),
#  ('Pacific', 'Daylight', 'Time'),
#  ('Kevin', 'Logan'),
#  ('State', 'Farm', 'Mutual', 'Automobile', 'Insurance', 'Co.'),
#  ('Burrillville',),
#  ('West', 'Germany'),
#  ('Mr.', 'Milunovich'),
#  ('Conning', '&', 'Co.'),
#  ('Texas',
#   ',',
#   'California',
#   ',',
#   'Colorado',
#   ',',
#   'Arizona',
#   'and',
#   'Florida'),
#  ('MMI', 'positions'),
#  ('Oct.', '29', ',', '1929'),
#  ('Dun', '&', 'Bradstreet', 'Corp.'),
#  ('Valley', 'Stream'),
#  ('Sweden',),
#  ('WTXF',),
#  ('Construction', 'Equipment', 'International'),
#  ('Mr.', 'Della', 'Femina'),
#  ('BanPonce', 'Corp.'),
#  ('Fina',),
#  ('Brands',),
#  ('J.M.', 'Cohen'),
#  ('Tom', 'Schumacher'),
#  ('Equitec',),
#  ('Orange',),
#  ('Wall', 'Street', 'estimates'),
#  ('A.G.', 'Edwards', '&', 'Sons', 'Inc.'),
#  ('RD',),
#  ('Chairman', 'Roger', 'W.', 'Johnson'),
#  ('El', 'Al', 'director', 'Rafi', 'Har-Lev'),
#  ('Goldman', ',', 'Sachs', '&', 'Co'),
#  ('Mr.', 'Mitchell', 'Travel', 'Service'),
#  ('Sydney',),
#  ('Briarcliff', 'Manor'),
#  ('Randy', 'Delchamps'),
#  ('Bateman', ',', 'Bryan', '&', 'Galles', 'Inc.'),
#  ('Salomon', 'Brothers', 'Inc'),
#  ('67-year-old', 'Mrs.', 'Thi'),
#  ('Digital', 'Equipment', 'Corp.'),
#  ('Batman',),
#  ('July', '31'),
#  ('Lincoln-Mercury', 'dealerships'),
#  ('JROE',),
#  ('Evelyn', 'Boccone'),
#  ('Salvadoran', 'President', 'Alfredo', 'Cristiani'),
#  ('BellSouth',),
#  ('K-H', 'Corp.'),
#  ('U.S.', 'companies'),
#  ('Monmouth',),
#  ('Germany',),
#  ('Pizza', 'Hut'),
#  ('Rep.', 'James', 'Oberstar'),
#  ('Chase', 'Manhattan', 'Corp.'),
#  ('Fred', 'Oldenburg'),
#  ('Woolworth', 'stores'),
#  ('Merrill', 'Lynch', '&', 'Co'),
#  ('Portfolio', 'B'),
#  ('Business', 'Tokyo', 'magazine'),
#  ('County', 'NatWest', 'Investment', 'Management', 'Ltd.'),
#  ('David', 'S.', 'Black'),
#  ('CONTINENTAL', 'Airlines'),
#  ('Michael', 'Dell'),
#  ('Raytheon', 'Co.'),
#  ('Cornell', 'University'),
#  ('Disney', 'toys'),
#  ('James', 'Daugherty'),
#  ('April', '15', ',', '1999'),
#  ('New', 'York', 'City', 'general', 'obligation', 'bonds'),
#  ('Berkshire', 'Hathaway'),
#  ('Manhattan', 'Life', 'Insurance', 'Co.'),
#  ('Remic', 'issuance'),
#  ('Chrysler', 'Corp.'),
#  ('Union', 'Pacific'),
#  ('Retired', 'couple'),
#  ('UAL', 'employees'),
#  ('Manufacturers',),
#  ('News', 'Corp.'),
#  ('Classic', 'Coke'),
#  ('MeraBank',),
#  ('Affiliated',),
#  ('Missouri',),
#  ('Harry', 'Manion'),
#  ('Yamaichi', 'International'),
#  ('Continental', 'Bank', 'Corp.'),
#  ('Mark', 'Steinkrauss'),
#  ('Los', 'Angeles-based', 'Farmers'),
#  ('NEW', 'ENGLAND', 'CRITICAL', 'CARE', 'Inc.'),
#  ('Toledo',),
#  ('Billie', 'Jean'),
#  ('Arkansas', 'Democrat', 'David', 'Pryor'),
#  ('Harbanse', 'Doman'),
#  ('AC&R', 'Advertising'),
#  ('Senate', 'Majority', 'Leader', 'George', 'Mitchell'),
#  ('Las', 'Vegas'),
#  ('Pharmaceuticals',),
#  ('Representatives',),
#  ('EC', 'inflation'),
#  ('Smith', 'College'),
#  ('Harold', 'W.', 'Smith', 'Sr.'),
#  ('Angel', 'Fire'),
#  ('Columbia', 'University'),
#  ('Mr.', 'Putka'),
#  ('House', 'and', 'Senate', 'negotiators'),
#  ('National', 'Assembly', 'deputies'),
#  ('Mexicana', 'de', 'Aviacion'),
#  ('Mr.', 'Biehl'),
#  ('Geoffrey', 'Goodfellow'),
#  ('President', 'Assad'),
#  ('Canadian', 'Pacific', 'Ltd.'),
#  ('Florida',
#   ',',
#   'Kentucky',
#   ',',
#   'Alabama',
#   ',',
#   'Tennessee',
#   'and',
#   'Louisiana'),
#  ('New', 'York-based', 'Hallwood', 'Group', 'Inc.'),
#  ('Consolidated', 'Rail', 'Corp.'),
#  ('Wall', 'Street', 'analysts'),
#  ('Jack', 'Grubman'),
#  ('Paramount', 'Pictures'),
#  ('Esso',),
#  ('Orin', 'Kramer'),
#  ('Tass',),
#  ('Noriega',),
#  ('Rainer', 'Eppelmann'),
#  ('Noranda', 'and', 'Trelleborg'),
#  ('Dr.', 'Bailit'),
#  ('Singapore',),
#  ('Diamond-Star', 'Motors', 'Corp.'),
#  ('Thomas', 'J.', 'Lipton', 'Co.'),
#  ('Short-term', 'Treasury', 'securities'),
#  ('Calif',),
#  ('American', 'Telephone', '&', 'Telegraph'),
#  ('GOP', 'state', 'Rep.', 'Stephen', 'Freind'),
#  ('FDA', 'approval'),
#  ('School',),
#  ('Guinness',),
#  ('Nov.', '3'),
#  ('Dow', 'Chemical', 'Co.'),
#  ('USA', 'Today'),
#  ('Perth',),
#  ('Addington',),
#  ('Mr.', 'Himebaugh'),
#  ('Ann', 'Adams', 'Webster'),
#  ('Viaje', 'a', 'la', 'Alcarria'),
#  ('Ms.', 'Tilly'),
#  ('Pepperidge', 'Farm'),
#  ('Jack', 'Rivkin'),
#  ('MCA', 'TV'),
#  ('Thomson', 'McKinnon', 'Inc.'),
#  ('Index',),
#  ('Pru-Bache',),
#  ('Sony',),
#  ('First', 'City'),
#  ('David', 'Hockney'),
#  ('Viacom',),
#  ('Nov.', '24', ',', '1994'),
#  ('IBM', 'and', 'MCA'),
#  ('mare-COOR',),
#  ('Mr.', 'Icahn'),
#  ('Florida',),
#  ('First', 'Gibraltar', 'Bank', 'F.S.B.'),
#  ('Marilyn', 'Monroe'),
#  ('Peter', 'J.', 'Canelo'),
#  ('Beefeater', 'gin'),
#  ('Timken',),
#  ('John', 'Markese'),
#  ('Big', 'Board', 'short', 'interest'),
#  ('Arby',),
#  ('Mr.', 'Seidman'),
#  ('Central', 'Bank'),
#  ('Mary', 'Rose', 'Oakar'),
#  ('Richard', 'M.', 'Greenwood'),
#  ('U.S.', 'aid'),
#  ('Samuel', 'James', 'Baker'),
#  ('Richard', 'Webb'),
#  ('Steven', 'B.', 'Enright'),
#  ('Mr.', 'Gourlay'),
#  ('Chase', 'Senior', 'Vice', 'President', 'George', 'Scandalios'),
#  ('Wichita',),
#  ('Merill', 'Lynch', 'International', 'Ltd'),
#  ('International', 'Proteins', 'Corp.'),
#  ('September', 'consumer', 'prices'),
#  ('Chancellor', 'Kohl'),
#  ('Michael', 'Baker'),
#  ('Deutsche', 'Bank', 'AG'),
#  ('May',),
#  ('AEW',),
#  ('Avdel',),
#  ('Eric', 'Philo'),
#  ('Greiner', 'Engineering'),
#  ('Io',),
#  ('Jan.', '28', ',', '1990'),
#  ('Capital', 'Supervisors', 'Inc.'),
#  ('Infotechnology', 'Inc.'),
#  ('Mr.', 'Schwartz'),
#  ('Trelleborg', 'and', 'Noranda'),
#  ('James', 'Baker'),
#  ('General', 'Electric', 'Co.'),
#  ('Byelorussia',),
#  ('California', 'state', 'and', 'local', 'municipal', 'debt'),
#  ('GE', 'technology'),
#  ('Atlanta',),
#  ('Federal', 'Reserve', 'banks', 'or', 'branches'),
#  ('Imasco',),
#  ('Income',),
#  ('Palo', 'Alto'),
#  ('Cupertino',),
#  ('Kinney', 'and', 'Foot', 'Locker', 'shoe', 'stores'),
#  ('Inland',),
#  ('Apple',
#   'Computer',
#   'Inc.',
#   'or',
#   'International',
#   'Business',
#   'Machines',
#   'Corp.',
#   'hardware'),
#  ('Westpac', 'Banking', 'Corp'),
#  ('N.M.',),
#  ('Refcorp',),
#  ('Connaught',),
#  ('Big', 'Board', 'volume'),
#  ('Tillinghast',),
#  ('Equitec', 'Chairman', 'Richard', 'L.', 'Saalfeld'),
#  ('European', 'Investment', 'Bank'),
#  ('Robert', 'Delaney'),
#  ('Apple',),
#  ('John', 'Morton'),
#  ('Sekisui', 'House'),
#  ('Grupo', 'Desc'),
#  ('Hepatitis', 'A'),
#  ('Capcom', 'Financial'),
#  ('Boris', '`', 'Bo', "'", 'Regaard'),
#  ('Merrill',),
#  ('business',),
#  ('Nevada',),
#  ('Scorpios',),
#  ('Bank', 'Bumiputra'),
#  ('King', 'Broadcasting', 'Co.'),
#  ('National', 'Steel', 'Corp'),
#  ('Sen.', 'Orrin', 'Hatch'),
#  ('Pa',),
#  ('B.A.T', 'Industries'),
#  ('Tandem', 'Computers', 'Inc.'),
#  ('February',),
#  ('DGAULT',),
#  ('Mr.', 'Mastro'),
#  ('Prudential-Bache', 'Capital', 'Funding'),
#  ('Richmond', ',', 'Va.-based', 'Universal', 'Corp.'),
#  ('LIN', 'Broadcasting', 'Corp.'),
#  ('R.I.',),
#  ('Better', 'Business', 'Bureaus'),
#  ('Greenwich',),
#  ('Walter', 'Yetnikoff'),
#  ('Gordon',),
#  ('Mark',),
#  ('Bass', 'PLC'),
#  ('Poodle',),
#  ('Saks', 'Fifth', 'Avenue'),
#  ('Societe', 'Commerciale'),
#  ('H&R', 'Block', 'tax', 'services'),
#  ('Southwestern', 'Bell', 'Telephone', 'Co.'),
#  ('IATA',),
#  ('Voyager',),
#  ('Armco', 'Inc.'),
#  ('Nov.', '8'),
#  ('Acton',),
#  ('Anterior', 'Technology'),
#  ('Pinpoint', 'Information', 'Corp.'),
#  ('Chevrolet',),
#  ('Automated', 'teller', 'machine', 'operations'),
#  ('Kraft', 'General', 'Foods'),
#  ('Candlestick', 'Park'),
#  ('Money',),
#  ('Chongju',),
#  ('Michael', 'W.', "O'Donnell"),
#  ('West', 'Texas', 'Intermediate'),
#  ('First', 'Fidelity'),
#  ('Aberdeen', 'Group', 'Inc'),
#  ('Lone', 'Star', 'Beer'),
#  ('Chemical', 'Waste', 'Management'),
#  ('Independents',),
#  ('Texas', 'Instruments'),
#  ('Friday', 'afternoon'),
#  ('Travis', 'Air', 'Force', 'Base'),
#  ('Total', 'Merkur', 'sales'),
#  ('Cormack', 'Enterprises', 'Inc.'),
#  ('Coastal', 'Corp.'),
#  ('Amex',),
#  ('International', 'Business', 'Machines', 'Corp.', 'computers'),
#  ('Texas', 'pride'),
#  ('October', '1982'),
#  ('Berkshire', 'Hathaway', 'Inc.'),
#  ('Paul', 'P.', 'Aniskovich', 'Jr.'),
#  ('Housing', 'and', 'Urban', 'Development'),
#  ('John', 'Sculley'),
#  ('SciMed', 'shares'),
#  ('J.P.', 'Morgan', 'Securities', 'Inc.'),
#  ('Series', 'trivia'),
#  ('Lake', 'Charles'),
#  ('British', 'Aerospace', 'PLC'),
#  ('Colgate', 'toothpaste'),
#  ('U.S.', 'history'),
#  ('Dec.', '1', ',', '1989'),
#  ('First', 'Iberian', 'Fund'),
#  ('Bernard', 'Savaiko'),
#  ('Michelle', 'Van', 'Cleave'),
#  ('Tax', 'Preparation'),
#  ('Maury', 'Elvekrog'),
#  ('Harley',),
#  ('Surety', 'Savings', 'Association'),
#  ('Sony', 'Corp.'),
#  ('Mr.', 'Trump'),
#  ('April', '4', ',', '1988'),
#  ('Empire-Berol',),
#  ('Sigma', 'Financial', 'Inc.'),
#  ('Mary', 'Spaulding'),
#  ('Beefeater',),
#  ('CSC',),
#  ('Schlumberger', 'Ltd.'),
#  ('Colorado', 'Springs'),
#  ('KTXL',),
#  ('W.', 'Mark', 'Goode'),
#  ('Mr.', 'Diebel'),
#  ('Alexandra', 'Armstrong', 'Advisors', 'Inc.'),
#  ('Compaq', 'Computer', 'Corp.'),
#  ('NRC', 'policy'),
#  ('Morrison', 'Knudsen'),
#  ('Congress',),
#  ('Financial', 'Affairs', 'Inc.'),
#  ('Singapore', 'and', 'Tokyo'),
#  ('Humana',),
#  ('London-based', 'WCRS'),
#  ('Winnebago',),
#  ('Quantum',),
#  ('Dr.', 'Frank', 'Provato'),
#  ('Teresa', 'de', 'Cepeda'),
#  ('Bernie', 'Ohls'),
#  ('Harry', 'B.', 'Helmsley'),
#  ('Ferdinand', 'Marcos'),
#  ('Norman', 'Abramson'),
#  ('U.S.', 'takeover-stock', 'speculators'),
#  ('Bethlehem', 'Steel', 'Corp.'),
#  ('U.S.', 'firms'),
#  ('Merck',),
#  ('South', 'Jersey'),
#  ('Safeco', 'Title', 'Insurance', 'Co.'),
#  ('U.S.', 'contributions'),
#  ('Hartford',),
#  ('Edward', 'J.', 'Tirello', 'Jr.'),
#  ('Finance',),
#  ('Nassau-Suffolk',),
#  ('Carnival', 'Cruise', 'Lines', 'Class', 'A'),
#  ('Santa', 'Fe', 'Pacific', 'Corp.'),
#  ('Noxell', 'common', 'and', 'Class', 'B', 'stock'),
#  ('A.P.', 'Green'),
#  ('Senate', 'Democrats'),
#  ('Mr.', 'Ross'),
#  ('Vista', 'Chemical', 'Co.'),
#  ('Rhode', 'Island'),
#  ('Sutro',),
#  ('Alan', 'Weston'),
#  ('USAir', 'Group'),
#  ('Vickers',),
#  ('Fla.',),
#  ('Texas', 'A&M'),
#  ('Barbie', 'doll'),
#  ('April', '6', ',', '1973'),
#  ('American', 'International', 'Group', 'Inc.'),
#  ('U.S.', 'operatives'),
#  ('Mr.', 'Sculley'),
#  ('Bristol',),
#  ('Thomas', 'M.', 'Bloch'),
#  ('Glen', 'Halva-Neubauer'),
#  ('International', 'Proteins', 'shares'),
#  ('New', 'York', 'Co.'),
#  ('July',),
#  ('Treasury', 'notes'),
#  ('Paribas', 'and', 'Lonrho'),
#  ('El', 'Espectador', 'journalists', 'and', 'staff'),
#  ('Thursday',),
#  ('Bob', 'Machon'),
#  ('Federal', 'Express', 'Corp.'),
#  ('AC&R', 'ADVERTISING'),
#  ('Johannesburg',),
#  ('Mr.', 'Sherlund'),
#  ('NatWest', 'and', 'Merrill'),
#  ('Capital', 'Cities-ABC'),
#  ('Morgan', 'Stanley', 'Capital', 'International', 'Perspective'),
#  ('Mr.', 'Markese'),
#  ('Trustcorp', 'Inc.'),
#  ('Ajinomoto',),
#  ('Health', 'and', 'Human', 'Services'),
#  ('Chevy', 'trucks'),
#  ('Streetspeak',),
#  ('Rutgers', 'University'),
#  ('Peter', 'G.', 'Diamandis'),
#  ('MacNamara', 'Clapp', '&', 'Klein'),
#  ('Oklahoma', 'official', 'Robert', 'Fulton'),
#  ('Tandy',),
#  ('Evans', 'Inc.'),
#  ('El', 'Al'),
#  ('Gov.', 'Kean'),
#  ('SNET', 'chairman', 'and', 'chief', 'executive', 'officer'),
#  ('Treasury', 'bills'),
#  ('Portland',),
#  ('Montgomery', 'Securities', 'Inc.'),
#  ('Iran',),
#  ('Guber',),
#  ('Pearl', 'Group'),
#  ('Olivetti', 'USA'),
#  ('Northrop',),
#  ('PPI',),
#  ('Clue',),
#  ('Mayor', 'Agnos'),
#  ('USAir',),
#  ('Fox', 'Broadcasting'),
#  ('Ho', 'Chi', 'Minh', 'City', 'party', 'secretary'),
#  ('Clinton', 'Gas', 'Systems', 'Inc.'),
#  ('Legal', '&', 'General'),
#  ('Steinhardt', 'Partners'),
#  ('Hanson', 'PLC'),
#  ('March', '31', ',', '1994'),
#  ('Delaware', 'Chancery', 'Court'),
#  ('Fridays',),
#  ('Baring', 'Brothers', '&', 'Co.'),
#  ('Newport',),
#  ('Nov.', '22'),
#  ('Alan', 'G.', 'Hassenfeld'),
#  ('Pinnacle', 'West', 'Capital', 'Corp.'),
#  ('Credit', 'Suisse', 'First', 'Boston', 'Ltd'),
#  ('Ameron',),
#  ('Prudential', 'Insurance', 'Co.'),
#  ('NASA',),
#  ('Susie', 'Diamond'),
#  ('Harrisburg',),
#  ('Fulton', 'Prebon'),
#  ('Bronson', ',', 'Bronson', '&', 'McKinnon'),
#  ('Los', 'Gatos'),
#  ('Irvine', 'Co.'),
#  ('April', '27'),
#  ('Hill', 'Street', 'Blues'),
#  ('Robert', 'W.', 'Kasten'),
#  ('Atchinson', 'County'),
#  ('Keizaikai',),
#  ('Bankers', 'Trust', 'Co'),
#  ('August', '1988'),
#  ('Robert', 'M.', 'White'),
#  ('Edward', 'J.', 'Campbell'),
#  ('Md',),
#  ('PaineWebber', 'Group', 'Inc.'),
#  ('Prof.', 'James', 'Tobin'),
#  ('Lai', 'Nguyen', 'An'),
#  ('FT-SE', '100', 'shares'),
#  ('Mr.', 'Parker'),
#  ('Minpeco', 'S.A.'),
#  ('United', 'Airlines', 'parent', 'UAL', 'Corp.'),
#  ('December', 'delivery', 'gold'),
#  ('NCNB', 'Corp.'),
#  ('Sacremento',),
#  ('Silicon', 'Valley'),
#  ('Terry', 'Pryce'),
#  ('Corroon', '&', 'Black'),
#  ('Spokane',),
#  ('Erdos', '&', 'Morgan', 'Inc.'),
#  ('Kate', 'Michelman'),
#  ('Khmer', 'Rouge', 'camps'),
#  ('Series', '1989'),
#  ('Loral',),
#  ('Saturday', 'night'),
#  ('Promotion',),
#  ('Fremont',),
#  ('WCRS', 'and', 'Eurocom'),
#  ('MC', 'SHIPPING', 'Inc.'),
#  ('John', 'Rohs'),
#  ('Raymond', 'Chandler'),
#  ('Bob', 'Barber'),
#  ('Keihin', 'Electric', 'Express', 'Railway', 'Co'),
#  ('Reggie', 'Jackson'),
#  ('Mr.', 'Corcoran'),
#  ('Bear', ',', 'Stearns'),
#  ('Mr.', 'Oriani'),
#  ('Hugo', 'Quackenbush'),
#  ('Oct',),
#  ('Federal', 'and', 'state', 'tax', 'enforcers'),
#  ('Shearson', 'Lehman', 'Hutton', 'Holdings', 'Inc.'),
#  ('WSJ', 'Oct.', '20', ',', '1989'),
#  ('Sotheby',),
#  ('Ontario',),
#  ('James', 'F.', 'Gero'),
#  ('Adsi', 'Inc.'),
#  ('Day', 'orders'),
#  ('Coal', 'prices'),
#  ('Mr.', 'Peterson'),
#  ('Oct.', '13'),
#  ('Chile', ',', 'Cuba', ',', 'Panama', 'or', 'Haiti'),
#  ('Massachusetts', 'Attorney', 'General', 'James', 'Shannon'),
#  ('Clinton',),
#  ('Pieter', 'Bruwer'),
#  ('Charles', 'Lieberman'),
#  ('Fuji', 'technology'),
#  ('Tandem', 'Computers'),
#  ('Peter', 'Isler'),
#  ('Control', 'Data', 'Corp'),
#  ('Papa',),
#  ('Bay', 'area', 'clients'),
#  ('Ms.', 'Levine'),
#  ('PPG',),
#  ('Irving',),
#  ('Analyst', 'James', 'Weil'),
#  ('American', 'Express', 'Information', 'Services'),
#  ('La', 'Familia', 'de', 'Hoy'),
#  ('Stop-Limit', 'Order'),
#  ('Emeryville',),
#  ('Land',),
#  ('Sally', 'Stewart'),
#  ('Mr.', 'Bush'),
#  ('Federal', 'Highway', 'Administrator', 'Thomas', 'Larson'),
#  ('London', 'brokers', 'County', 'NatWest', 'WoodMac'),
#  ('London', 'bullion', 'brokers'),
#  ('Frank', 'Salerno'),
#  ('Lewis', 'Galoob', 'Toys'),
#  ('Deloitte', ',', 'Haskins', '&', 'Sells', 'International'),
#  ('Nixon', ',', 'Hargrave', ',', 'Devans', '&', 'Doyle'),
#  ('Overnite', 'Transportation', 'earnings'),
#  ('Dec.', '15'),
#  ('William', 'Seidman'),
#  ('Commons',),
#  ('Southdown',),
#  ('Romania',),
#  ('Tan', 'Sri', 'Basir'),
#  ('January', '1989'),
#  ('California',),
#  ('Mellon', 'Bank', 'Corp.'),
#  ('Polygram', 'Pictures'),
#  ('Mayor', 'Carolyn', 'Robinson'),
#  ('Suggestion', 'Systems'),
#  ('Mr.', 'Breene'),
#  ('David', 'M.', 'Carroll'),
#  ('Harvard',),
#  ('February', '1987'),
#  ('Peter', 'Jarvis'),
#  ('Torrence', 'Johnson'),
#  ('Mattel', 'Inc.'),
#  ('Cipher', 'Data', 'Products', 'Inc.'),
#  ('BankAmerica',),
#  ('Triad',),
#  ('Bell', 'Atlantic'),
#  ('Paramount', 'Domestic', 'TV'),
#  ('Professor',),
#  ('CalFed',),
#  ('Mass',),
#  ('Ms.', 'Masaki-Schatz'),
#  ('Fed', 'credit', 'policy', 'changes'),
#  ('Jamie', 'Kellner'),
#  ('Bozell', 'Inc.'),
#  ('Resolution', 'Trust', 'Corp.'),
#  ('Farmers',),
#  ('Peter', 'S.', 'Willmott'),
#  ('Sept.', '20'),
#  ('New', 'Jersey', 'Turnpike', 'Authority'),
#  ('Mr.', 'Jackson', "'s"),
#  ('Timken', 'Co.'),
#  ('Candlestick',),
#  ('Hendrik', 'F.', 'Verwoerd'),
#  ('Aetna', 'Life', '&', 'Casualty', 'Insurance', 'Co.'),
#  ('Marx',),
#  ('General', 'Motors', 'Corp.'),
#  ('Mr.', 'Greenberg'),
#  ('Louisville',),
#  ('Merrill', 'Lynch'),
#  ('Miss.',),
#  ('State', ',', 'Justice', 'and', 'Commerce'),
#  ('Mark', 'Cremonie'),
#  ('Sanford', 'C.', 'Bernstein', '&', 'Co.'),
#  ('J.P.', 'Morgan', '&', 'Co.'),
#  ('Western', 'Europe'),
#  ('HUD', 'officials'),
#  ('Turnaround', 'Letter'),
#  ('Mr.', 'Delchamps'),
#  ('Valley', 'National'),
#  ('Himont',),
#  ('DDB', 'Needham'),
#  ('FileNet',),
#  ('Inmac',),
#  ('McDonald',),
#  ('Mobile', 'Communications', 'Corp.'),
#  ('Wednesday', 'or', 'Thursday'),
#  ('First', 'Fidelity', 'Bancorp.'),
#  ('Vice', 'President', 'Dan', 'Quayle'),
#  ('AMR',),
#  ('Duff', '&', 'Phelps', 'Inc'),
#  ('NORTHERN', 'CALIFORNIA'),
#  ('Dow', 'Jones', 'Professional', 'Investor', 'Report'),
#  ('Winter', 'Carnival', 'week'),
#  ('Aetna',),
#  ('Martin', 'J.', '``', 'Hoot', "''", 'McInerney'),
#  ('Frederick', 'Smith'),
#  ('Industrial', 'output'),
#  ('MMS', 'International'),
#  ('DILLARD', 'DEPARTMENT', 'STORES', 'Inc.'),
#  ('October',),
#  ('Allstate', 'Insurance', 'Co.'),
#  ('Jerry', 'Lackey'),
#  ('Guber', 'Peters', 'pictures'),
#  ('Kansas', 'and', 'Texas'),
#  ('Ltd',),
#  ('Ala.',),
#  ('Idaho',),
#  ('Sirota', ',', 'Alper', '&', 'Pfau'),
#  ('Atlantis',),
#  ('Mr.', 'Hicks'),
#  ('American', 'Express', 'Information', 'Services', 'Co'),
#  ('Royal', 'Dutch\\/Shell', 'Group'),
#  ('Cineplex',),
#  ('STOCK', 'MARKET', 'PATOIS'),
#  ('Saturdays', ',', 'Sundays', 'and', 'Mondays'),
#  ('Pemex', 'managers'),
#  ('Dec.', '29', ',', '1988'),
#  ('Marshall', 'Coleman'),
#  ('Ms.', 'Bettner'),
#  ('Fidelity',),
#  ('Bank', 'Julius', 'Baer'),
#  ('Hunt', 'Valley'),
#  ('Value', 'Matrix', 'Management', 'Inc.'),
#  ('Harris', 'Amhowitz'),
#  ('Sam', 'Whitbread'),
#  ('Oct.', '17'),
#  ('Christmas',),
#  ('LifeSpan', 'Inc.'),
#  ('Oct.', '19', ',', '1987'),
#  ('CD',),
#  ('GTE', 'officials'),
#  ('Fernando', 'Volio'),
#  ('Mr.', 'McClelland'),
#  ('Schering-Plough', 'Health', 'Care', 'Products'),
#  ('Citicorp', 'and', 'Chase'),
#  ('Silver', 'Spring'),
#  ('UAL', 'shares'),
#  ('Lowell',),
#  ('Kidder', 'Peabody'),
#  ('Chernobyl',),
#  ('Republican', 'freeholders'),
#  ('Eddie', 'Mahe'),
#  ('San', 'Jose'),
#  ('Metropolitan', 'Life', 'Insurance', 'Co.'),
#  ('Louisiana', 'officials'),
#  ('Heberto', 'Castillo'),
#  ('UAL', 'flight', 'attendants'),
#  ('Crest',),
#  ('Paul', 'Fireman'),
#  ('Hilton',),
#  ('Mr.', 'Gras'),
#  ('Winter', 'Haven'),
#  ('Navin', 'Vyas'),
#  ('Ameritech', 'Corp.'),
#  ('N.J.',),
#  ('Banc', 'One', 'Corp.'),
#  ('NATO',),
#  ('Ben', 'Hanauer'),
#  ('Union', 'Pacific', 'Corp.'),
#  ('Amex', 'short', 'interest'),
#  ('Honduras',),
#  ('Robert', 'Lekberg'),
#  ('Garden', 'City'),
#  ('International', 'Forest', 'Products', 'Ltd.'),
#  ('Enserch', 'Corp.'),
#  ('Carriers',),
#  ('Martin', 'Fleischmann'),
#  ('Dec.', '30'),
#  ('Mr.', 'Keith'),
#  ('Georgia-Pacific', 'stock'),
#  ('Fannie', 'Mae', '9', '%', 'securities'),
#  ('Providence',),
#  ('Commerce',),
#  ('KIM',),
#  ('Walter', 'H.', 'Monteith', 'Jr.'),
#  ('Anton', 'Amon'),
#  ('Standard', '&', 'Poor'),
#  ('International', 'Business', 'Machines', 'Corp'),
#  ('Chairman', 'Richard', 'M.', 'Morrow'),
#  ('Sandinista', 'propaganda'),
#  ('Casablanca', 'Records', 'and', 'Filmworks'),
#  ('Varity', 'Corp.'),
#  ('Jacob', 'Dreyer'),
#  ('Cotton', 'Daly'),
#  ('Shearson', 'shares'),
#  ('Santa', 'Cruz', 'County'),
#  ('Sperry', 'Corp'),
#  ('New', 'York'),
#  ('Christopher', 'Whittington'),
#  ('Ragu', 'spaghetti', 'sauce'),
#  ('Stacy', 'Kotman'),
#  ('East', 'Rock', 'Partners', 'L.P'),
#  ('Aqua', 'Net', 'hairspray'),
#  ('Teamsters',),
#  ('Ms.', 'Tharp'),
#  ('Polycast', 'Technology', 'Corp'),
#  ('Gen.', 'Manuel', 'Noriega'),
#  ('Reuben', 'Mark'),
#  ('Deloitte', 'and', 'Touche', 'world-wide'),
#  ('SH', 'Oil'),
#  ('Agricola',),
#  ('January',),
#  ('Moscow',),
#  ('House', 'Speaker', 'James', 'Wright'),
#  ('Della', 'Femina', 'McNamee'),
#  ('Nguyen', 'Van', 'Chan'),
#  ('Ignazio', 'J.', 'Ruvolo'),
#  ('Governors',),
#  ('Block',),
#  ('NYSE',),
#  ('Avianca',),
#  ('St.', 'Johns', 'River', 'Water', 'Management', 'District'),
#  ('Webster', 'Financial', 'Corp.'),
#  ('DOE',),
#  ('OPEC',),
#  ('AT&T', 'shares'),
#  ('Dell', 'Computer'),
#  ('Individual', 'Inc.'),
#  ('Palms',),
#  ('Craig', 'O.', 'McCaw'),
#  ('Northern', 'California', 'home', 'prices'),
#  ('Europeans',),
#  ('Mr.', 'Smalling'),
#  ('Englewood',),
#  ('John', 'Gargan'),
#  ('House', 'Appropriations', 'Committee', 'Chairman', 'Jamie', 'Whitten'),
#  ('Investigation',),
#  ('Beauregard',),
#  ('Mr.', 'Vyas'),
#  ('Norton', 'and', 'GE'),
#  ('Granges',),
#  ('Series', '105'),
#  ('Northern', 'California'),
#  ('Saab',),
#  ('Cowan', '&', 'Owen'),
#  ('Carter', 'Hawley', 'Hale', 'Stores', 'Inc.'),
#  ('Stokely',),
#  ('Hustead',),
#  ('Wednesday', 'morning'),
#  ('Millicom', 'Inc.'),
#  ('Seagate',),
#  ('Chicago', 'federal', 'court'),
#  ('John', 'S.', 'Reidy'),
#  ('County', 'NatWest', 'Ltd.'),
#  ('East', 'Germans'),
#  ('Prudential-Bache', 'Securities', 'Inc.'),
#  ('SAMURAI',),
#  ('Peter',),
#  ('Lloyd', 'Bentsen'),
#  ('Multiflow', 'Computer', 'Inc.'),
#  ('Cathay', 'Pacific', 'Airways'),
#  ('August', '30'),
#  ('Peter', 'Appert'),
#  ('John', 'Hancock', 'Freedom', 'Securities'),
#  ('Senator', 'John', 'Kerry'),
#  ('International', 'Business', 'Machines', 'Corp.'),
#  ('Maury', 'Kelley'),
#  ('Tokyo', 'market', 'participants'),
#  ('Judge', 'Louis', 'L.', 'Stanton'),
#  ('Pemex',),
#  ('Betty', 'Lombardi'),
#  ('Bear', ',', 'Stearns', '&', 'Co'),
#  ('America',),
#  ('Rwanda',),
#  ('Ms.', 'Smith'),
#  ('T.', 'Rowe', 'Price', 'mutual-fund', 'groups'),
#  ('Renault',),
#  ('Rep.', 'Stephen', 'Neal'),
#  ('Syria', ',', 'Iran', 'and', 'Iraq'),
#  ('Minpeco', 'attorney', 'Thomas', 'Gorman'),
#  ('Supplemental', 'Security', 'Income', 'payments'),
#  ('Miller', 'Brewing', 'Co.'),
#  ('Trinova', 'third-quarter', 'loss'),
#  ('Jeffrey', 'B.', 'Lane'),
#  ('Mr.', 'Garcia'),
#  ('Trans', 'World', 'Airlines'),
#  ('Time',),
#  ('Marshall', 'Field'),
#  ('Valley', 'National', 'Corp.'),
#  ('Ariz',),
#  ('Ford', 'and', 'Saab'),
#  ('Leo', 'J.', 'Shapiro', '&', 'Associates'),
#  ('S.C',),
#  ('Mansion', 'House'),
#  ('Prudential-Bache',),
#  ('Newport', 'News'),
#  ('Harold', 'Hershhenson'),
#  ('Walt', 'Disney', 'Co.'),
#  ('Old', 'network', 'hands'),
#  ('New',
#   'York',
#   'Times',
#   'Co.',
#   'chairman',
#   'and',
#   'chief',
#   'executive',
#   'officer'),
#  ('General', 'Cinema', 'Corp.'),
#  ('Location', 'Management'),
#  ('Midnight', 'Express'),
#  ('Barclays', 'de', 'Zoete', 'Wedd'),
#  ('Compaq', 'Computer'),
#  ('Kean', 'forces'),
#  ('Sapporo',),
#  ('Bavaria', 'and', 'Baden-Wuerttemberg'),
#  ('Cleveland',),
#  ('Ticor', 'Title', 'Insurance', 'Co.'),
#  ('Mrs.', 'Sutcliffe'),
#  ('First', 'Bank', 'System'),
#  ('Stewart', 'Gilchrist'),
#  ('National', 'Advanced', 'Systems'),
#  ('Fiat', 'S.p', '.', 'A.'),
#  ('Mr.', 'Luthringshausen'),
#  ('Los', 'Angeles-based', 'H.F.', 'Ahmanson'),
#  ('RJR', 'Nabisco', 'Inc.'),
#  ('Grace', 'Energy'),
#  ('William', 'Sullivan', 'Jr.'),
#  ('Sen.', 'John', 'Kerry'),
#  ('Clifford', 'Sayre'),
#  ('Chevy',),
#  ('Alex', 'Kroll'),
#  ('International', 'Data', 'Corp.'),
#  ('Chez', 'Panisse'),
#  ('Wisconsin',),
#  ('New',
#   'York',
#   'consulting',
#   'firm',
#   'Simat',
#   ',',
#   'Helliesen',
#   '&',
#   'Eichner',
#   'Inc'),
#  ('Morrison', 'Knudsen', 'Corp.'),
#  ('HOLLYWOOD', 'Inc.'),
#  ('Fort', 'Lauderdale'),
#  ('Stanley', 'Rose'),
#  ('Security', 'Pacific', 'Corp.'),
#  ('Antique', 'Dealers'),
#  ('Stinson', 'Beach'),
#  ('Champion',),
#  ('Kollmorgen',),
#  ('Afrikanerdom',),
#  ('Burton', 'Lee'),
#  ('Sibra', 'Products', 'Inc.'),
#  ('San', 'Francisco-based', 'Pacific', 'Telesis'),
#  ('U.S.', 'intelligence'),
#  ('Royal', 'Insurance'),
#  ('Takanori', 'Mizuno'),
#  ('Cessna',),
#  ('Western', 'Digital'),
#  ('Commodore', 'International'),
#  ('Ky',),
#  ('San', 'Francisco', 'area', 'officials'),
#  ('Mr.', 'Sugarman'),
#  ('Assistant', 'U.S.', 'Attorney', 'Terry', 'Hart'),
#  ('Sen.', 'Mitchell'),
#  ('Dean', 'Witter'),
#  ('Douglas', 'B.', 'Evans'),
#  ('National', 'Health', 'Care', 'Affiliates', 'Inc.'),
#  ('November', 'delivery'),
#  ('Ford', 'Motor', 'Co.'),
#  ('South', 'Carolina'),
#  ('Capital', 'Holding'),
#  ('Tokyo',),
#  ('T.', 'Rowe', 'Price'),
#  ('Abortion',),
#  ('Sam', 'Ginn'),
#  ('Healthcare',),
#  ('Paramount', 'Chairman', 'Martin', 'Davis'),
#  ('Grand', 'Union', 'Co.'),
#  ('Mr.', 'Maynard'),
#  ('Kurds',),
#  ('Scottish', 'Amicable'),
#  ('Bonwit',
#   'Teller',
#   'and',
#   'B.',
#   'Altman',
#   'parent',
#   'L.J.',
#   'Hooker',
#   'Corp.'),
#  ('Haskins', '&', 'Sells'),
#  ('Highland', 'Valley'),
#  ('Nov.', '14'),
#  ('Steven', 'G.', 'Einhorn'),
#  ('Frederick', 'G.', 'Hicks'),
#  ('Egon', 'Krenz'),
#  ('Michael', 'Simmons'),
#  ('Foreign', 'Minister', 'Hans-Dietrich', 'Genscher'),
#  ('H&R', 'Block', 'stock'),
#  ('Norfolk',),
#  ('Long', 'Island'),
#  ('Tegucigalpa',),
#  ('American', 'Medical'),
#  ('Alfred', 'Goldman'),
#  ('Pasquale', 'Pignatelli'),
#  ('Trinova',),
#  ('Becton', ',', 'Dickinson', '&', 'Co.'),
#  ('Messrs.', 'Fleischmann', 'and', 'Pons'),
#  ('New', 'Yorkers'),
#  ('Sunday', 'River'),
#  ('El', 'Monte'),
#  ('July', '11', ',', '1988'),
#  ('Philippe', 'Gras'),
#  ('United', 'Egg', 'Producers'),
#  ('St.', 'Petersburg'),
#  ('John', 'C.', 'Burton'),
#  ('Heineken',),
#  ('TransAtlantic', 'Holdings', 'PLC'),
#  ('Chemical', 'Securities', 'Inc.'),
#  ('Joan', 'Tharp'),
#  ('NBC',),
#  ('Georgia-Pacific', 'Corp.'),
#  ('United', 'Airlines', 'parent'),
#  ('Anglo-Dutch', 'Unilever', 'Group'),
#  ('Democratic', 'Gov.', 'James', 'Blanchard'),
#  ('Douglas', 'Watson'),
#  ('HUD', 'loans'),
#  ('East', 'Germany'),
#  ('Soo', 'Line', 'shares'),
#  ('maitre', "'d"),
#  ('Mr.', 'Whitten'),
#  ('U.S.', 'government', 'bonds'),
#  ('Merkur', 'prices'),
#  ('Warren', 'E.', 'Buffett'),
#  ('Consultant', 'John', 'Keller'),
#  ('Chrysler', 'officials'),
#  ('Sports',),
#  ('Kary', 'Moss'),
#  ('Lockheed', 'Corp.'),
#  ('Irvine',),
#  ...}

# %%
list(ne_set)[:10]
# Out:
# [('Streetspeak',),
#  ('Valley', 'National', 'Corp.'),
#  ('Chemical', 'Securities', 'Inc.'),
#  ('National', 'Westminister', 'Bank'),
#  ('Nov.', '15', ',', '1999'),
#  ('San', 'Francisco', 'International'),
#  ('Merrill', 'Lynch', 'Capital', 'Markets'),
#  ('Hollywood',),
#  ('Mary', 'E.', 'Sommer'),
#  ('John', 'S.', 'Reidy')]

# %% [markdown]
# ### Creating a small set

# %% [markdown]
# To run the subsequent experiments faster, you will limit the dataset to the entities starting with letter _K_. I chose this letter, because it corresponded to one of the smallest sets. You will call the resulting set: `ne_small_set`. Feel free to use the full set after you have completed this assignment.

# %%
ne_small_set = set()
for tup in ne_set:
    if tup[0][0] == 'K':
        ne_small_set.add(tup)

# %%
ne_small_set
# Out:
# {('K', 'mart', 'Corp.', 'Chairman', 'Joseph', 'E.', 'Antonini'),
#  ('K-H', 'Corp.'),
#  ('KIM',),
#  ('KLM', 'Royal', 'Dutch', 'Airlines'),
#  ('KPMG', 'Peat', 'Marwick'),
#  ('KTXL',),
#  ('Kabul',),
#  ('Kacy', 'McClelland'),
#  ('Kaitaia',),
#  ('Kajima',),
#  ('Kansas',),
#  ('Kansas', 'Power'),
#  ('Kansas', 'and', 'Texas'),
#  ('Karen', 'Olshan'),
#  ('Kary', 'Moss'),
#  ('Kasler', 'Corp.'),
#  ('Kate', 'Michelman'),
#  ('Kathe', 'Dillmann'),
#  ('Kathie', 'Huff'),
#  ('Kathie', 'Roberts'),
#  ('Kathryn', 'McGrath'),
#  ('Kathy', 'Stanwick'),
#  ('Katonah',),
#  ('Kawasaki', 'Steel'),
#  ('Ke', 'Zaishuo'),
#  ('Kean', 'forces'),
#  ('Keefe', ',', 'Bruyette', '&', 'Woods', 'Inc.'),
#  ('Keihin', 'Electric', 'Express', 'Railway', 'Co'),
#  ('Keith', 'L.', 'Fogg'),
#  ('Keith', 'Mulrooney'),
#  ('Keizaikai',),
#  ('Keizaikai', 'Corp.'),
#  ('Kemper',),
#  ('Kenneth', 'A.', 'Eldred'),
#  ('Kenneth', 'Abraham'),
#  ('Kenneth', 'H.', 'Olsen'),
#  ('Kenneth', 'T.', 'Rosen'),
#  ('Kent', 'Neal'),
#  ('Kenton',),
#  ('Kentucky',),
#  ('Kentucky', 'Fried', 'Chicken', 'stores'),
#  ('Kevin', 'Logan'),
#  ('Khmer', 'Rouge', 'camps'),
#  ('Khost',),
#  ('Kidder', ',', 'Peabody', '&', 'Co'),
#  ('Kidder', ',', 'Peabody', '&', 'Co.'),
#  ('Kidder', 'Peabody'),
#  ('Kim', 'Schwartz'),
#  ('Kimberly', 'Ann', 'Smith'),
#  ('King', 'Broadcasting', 'Co.'),
#  ('Kinney', 'and', 'Foot', 'Locker', 'shoe', 'stores'),
#  ('Kirin',),
#  ('Kirin', 'Brewery'),
#  ('Kitchen',),
#  ('Kleinwort', 'Benson', 'Government', 'Securities', 'Inc.'),
#  ('Kleinwort', 'Benson', 'North', 'America'),
#  ('Knoxville',),
#  ('Ko', 'Shioya'),
#  ('Kobe', 'Steel'),
#  ('Kobe', 'Steel', 'Ltd.'),
#  ('Kodak',),
#  ('Kollmorgen',),
#  ('Kraft', 'General', 'Foods'),
#  ('Kremlin', 'wrangling'),
#  ('Krenz',),
#  ('Kringle', 'fares'),
#  ('Kroger', 'Co'),
#  ('Kuala', 'Lumpur'),
#  ('Kumagai-Gumi',),
#  ('Kurds',),
#  ('Kursk', 'and', 'Smolensk'),
#  ('Kurt', 'Hager'),
#  ('Kwek', 'Hong', 'Png'),
#  ('Ky',),
#  ('Ky.',),
#  ('Kyocera',)}

# %%
ne_small_set
# Out:
# [('Kathie', 'Roberts'),
#  ('Keith', 'L.', 'Fogg'),
#  ('Kansas', 'and', 'Texas'),
#  ('Kringle', 'fares'),
#  ('Ky.',),
#  ('Keith', 'Mulrooney'),
#  ('Kirin', 'Brewery'),
#  ('Kent', 'Neal'),
#  ('Kenneth', 'T.', 'Rosen'),
#  ('Kuala', 'Lumpur'),
#  ('Keizaikai', 'Corp.'),
#  ('Kidder', ',', 'Peabody', '&', 'Co.'),
#  ('Kathryn', 'McGrath'),
#  ('Kobe', 'Steel', 'Ltd.'),
#  ('Kathie', 'Huff'),
#  ('Kary', 'Moss'),
#  ('Kathy', 'Stanwick'),
#  ('Khost',),
#  ('Ke', 'Zaishuo'),
#  ('Kidder', ',', 'Peabody', '&', 'Co'),
#  ('Kirin',),
#  ('KTXL',),
#  ('Kabul',),
#  ('Kaitaia',),
#  ('Kidder', 'Peabody'),
#  ('Kevin', 'Logan'),
#  ('King', 'Broadcasting', 'Co.'),
#  ('Kinney', 'and', 'Foot', 'Locker', 'shoe', 'stores'),
#  ('Kimberly', 'Ann', 'Smith'),
#  ('Kwek', 'Hong', 'Png'),
#  ('Keihin', 'Electric', 'Express', 'Railway', 'Co'),
#  ('Kraft', 'General', 'Foods'),
#  ('Kenneth', 'A.', 'Eldred'),
#  ('K', 'mart', 'Corp.', 'Chairman', 'Joseph', 'E.', 'Antonini'),
#  ('KLM', 'Royal', 'Dutch', 'Airlines'),
#  ('Kacy', 'McClelland'),
#  ('Kitchen',),
#  ('Kathe', 'Dillmann'),
#  ('Keizaikai',),
#  ('Knoxville',),
#  ('KPMG', 'Peat', 'Marwick'),
#  ('Krenz',),
#  ('Katonah',),
#  ('K-H', 'Corp.'),
#  ('Kemper',),
#  ('Kremlin', 'wrangling'),
#  ('Kentucky', 'Fried', 'Chicken', 'stores'),
#  ('Kate', 'Michelman'),
#  ('Kleinwort', 'Benson', 'North', 'America'),
#  ('Kobe', 'Steel'),
#  ('Kansas',),
#  ('Kleinwort', 'Benson', 'Government', 'Securities', 'Inc.'),
#  ('Kawasaki', 'Steel'),
#  ('Kurds',),
#  ('Kollmorgen',),
#  ('Karen', 'Olshan'),
#  ('Kroger', 'Co'),
#  ('Kenton',),
#  ('Kurt', 'Hager'),
#  ('Kodak',),
#  ('Kentucky',),
#  ('Keefe', ',', 'Bruyette', '&', 'Woods', 'Inc.'),
#  ('KIM',),
#  ('Kursk', 'and', 'Smolensk'),
#  ('Kenneth', 'H.', 'Olsen'),
#  ('Kim', 'Schwartz'),
#  ('Kean', 'forces'),
#  ('Ky',),
#  ('Kyocera',),
#  ('Kumagai-Gumi',),
#  ('Kenneth', 'Abraham'),
#  ('Ko', 'Shioya'),
#  ('Kansas', 'Power'),
#  ('Khmer', 'Rouge', 'camps'),
#  ('Kajima',),
#  ('Kasler', 'Corp.')]

# %% [markdown]
# ## Resolving the entities

# %% [markdown]
# You will now implement a simple method to find the named entities from the previous exercise in Wikipedia and Wikidata.

# %% [markdown]
# First, look at a few entities in your set and find:
# 1. a few entities that you think are in wikipedia,
# 2. entities that will not be in wikipedia, and
# 3. entities that you think are ambiguous: An entity that may correspond to two or more things.
#
# You will describe your findings in the report.

# %% [markdown]
# ### A function to lookup entities

# %% [markdown]
# Read the function below and try to understand what it means. You will describe it in your report.

# %%
def wikipedia_lookup(ner, base_url='https://en.wikipedia.org/wiki/'): # change sv to en for english
    try:
        url_en = base_url + ' '.join(ner)
        print(url_en)
        html_doc = requests.get(url_en).text
        parse_tree = bs4.BeautifulSoup(html_doc, 'html.parser')
        entity_id = parse_tree.find("a", {"accesskey": "g"})['href']
        head_id, entity_id = os.path.split(entity_id)
        return entity_id
    except:
        pass
        #print('Not found in: ', url_en)
    entity_id = 'UNK'
    return entity_id

# %% [markdown]
# Write a function to run the lookup and keep the resolved entities (only the resolved entities). You will call it `ne_ids_en`

# %%
def ne_ids_en(lilset):
    ne = []
    for tup in lilset:
        if wikipedia_lookup(tup) != 'UNK':
            ne.append((tup, wikipedia_lookup(tup)))
    
    return ne

# %%
ne_ids_en = ne

# %%
ne = ne_ids_en(ne_small_set) 
ne
# Out:
# [(('Kabul',), 'Q5838'),
#  (('KIM',), 'Q224736'),
#  (('Ky.',), 'Q225951'),
#  (('Kenneth', 'Abraham'), 'Q59268486'),
#  (('Kobe', 'Steel'), 'Q1730802'),
#  (('Khost',), 'Q386682'),
#  (('Kyocera',), 'Q745099'),
#  (('KLM', 'Royal', 'Dutch', 'Airlines'), 'Q181912'),
#  (('Kitchen',), 'Q43164'),
#  (('Kirin',), 'Q297659'),
#  (('Ky',), 'Q225951'),
#  (('Kenton',), 'Q358393'),
#  (('KPMG', 'Peat', 'Marwick'), 'Q493751'),
#  (('Knoxville',), 'Q185582'),
#  (('Krenz',), 'Q21512656'),
#  (('Kwek', 'Hong', 'Png'), 'Q10559663'),
#  (('Kidder', 'Peabody'), 'Q3196386'),
#  (('KTXL',), 'Q6339344'),
#  (('Kenneth', 'H.', 'Olsen'), 'Q454315'),
#  (('Kuala', 'Lumpur'), 'Q1865'),
#  (('Kurds',), 'Q12223'),
#  (('Kurt', 'Hager'), 'Q95367'),
#  (('Kraft', 'General', 'Foods'), 'Q327751'),
#  (('Katonah',), 'Q2888777'),
#  (('Kaitaia',), 'Q257417'),
#  (('Kemper',), 'Q126993'),
#  (('Kirin', 'Brewery'), 'Q13403399'),
#  (('Kajima',), 'Q1081154'),
#  (('Kansas',), 'Q1558'),
#  (('Kawasaki', 'Steel'), 'Q6379829'),
#  (('Kentucky',), 'Q1603'),
#  (('Kodak',), 'Q486269'),
#  (('Kate', 'Michelman'), 'Q785671')]

# %% [markdown]
# Sometimes, entities need a confirmation. You will apply the resolution with the Swedish wikipedia.

# %%
ne_ids_sv = ne_ids_en(ne_small_set) 
ne_ids_sv
# Out:
# [(('Kabul',), 'Q5838'),
#  (('KIM',), 'Q224736'),
#  (('Khost',), 'Q386682'),
#  (('KLM', 'Royal', 'Dutch', 'Airlines'), 'Q181912'),
#  (('Kitchen',), 'Q952431'),
#  (('Kirin',), 'Q297659'),
#  (('Kenton',), 'Q358393'),
#  (('Knoxville',), 'Q232749'),
#  (('Kuala', 'Lumpur'), 'Q1865'),
#  (('Kraft', 'General', 'Foods'), 'Q12857502'),
#  (('Kroger', 'Co'), 'Q153417'),
#  (('Kansas',), 'Q1558'),
#  (('Kentucky',), 'Q1603'),
#  (('Kodak',), 'Q486269')]

# %% [markdown]
# You will compute the intersection of the two sets. You will assign it to a list that you will sort and that you will call: `confirmed_ne_en_sv`.

# %%
confirmed_ne_en_sv = []
for t in ne_ids_sv:
    for c in ne_ids_en:
        if t[0] in c:
            confirmed_ne_en_sv.append(t)
        
confirmed_ne_en_sv.sort()

# %%
confirmed_ne_en_sv
# Out:
# [(('KIM',), 'Q224736'),
#  (('KLM', 'Royal', 'Dutch', 'Airlines'), 'Q181912'),
#  (('Kabul',), 'Q5838'),
#  (('Kansas',), 'Q1558'),
#  (('Kenton',), 'Q358393'),
#  (('Kentucky',), 'Q1603'),
#  (('Khost',), 'Q386682'),
#  (('Kirin',), 'Q297659'),
#  (('Kitchen',), 'Q952431'),
#  (('Knoxville',), 'Q232749'),
#  (('Kodak',), 'Q486269'),
#  (('Kraft', 'General', 'Foods'), 'Q12857502'),
#  (('Kuala', 'Lumpur'), 'Q1865')]

# %%
confirmed_ne_en_sv

# %% [markdown]
# The first items in your list should look like:
# ```
# [(('KIM',), 'Q224736'),
#  (('KLM', 'Royal', 'Dutch', 'Airlines'), 'Q181912'),
#  ...
# ]
# ```

# %% [markdown]
# ## Submission

# %% [markdown]
# When you have written all the code and run all the cells, fill in your ID and as well as the name of the notebook.

# %%
STIL_ID = ["fe7744se-s", "an0173ti-s"] # Write your stil ids as a list
CURRENT_NOTEBOOK_PATH = os.path.join(os.getcwd(), 
                                     "4-chunker.ipynb") # Write the name of your notebook

# %% [markdown]
# The submission code will send your answer. It consists of the baseline score, the improved machine-learning score, and the confirmed entities.

# %%
import json
ANSWER = json.dumps({'baseline_score': baseline_score,
                    'improved_ml_score': improved_ml_score,
                    'confirmed_ne_en_sv': confirmed_ne_en_sv})
ANSWER
# Out:
# '{"baseline_score": 0.770671072299583, "improved_ml_score": 0.9265266775640221, "confirmed_ne_en_sv": [[["KIM"], "Q224736"], [["KLM", "Royal", "Dutch", "Airlines"], "Q181912"], [["Kabul"], "Q5838"], [["Kansas"], "Q1558"], [["Kenton"], "Q358393"], [["Kentucky"], "Q1603"], [["Khost"], "Q386682"], [["Kirin"], "Q297659"], [["Kitchen"], "Q952431"], [["Knoxville"], "Q232749"], [["Kodak"], "Q486269"], [["Kraft", "General", "Foods"], "Q12857502"], [["Kuala", "Lumpur"], "Q1865"]]}'

# %% [markdown]
# Now the moment of truth:
# 1. Save your notebook and
# 2. Run the cells below

# %%
SUBMISSION_NOTEBOOK_PATH = CURRENT_NOTEBOOK_PATH + ".submission.bz2"

# %%
import bz2
ASSIGNMENT = 4
API_KEY = "f581ba347babfea0b8f2c74a3a6776a7"

# Copy and compress current notebook
with bz2.open(SUBMISSION_NOTEBOOK_PATH, mode="wb") as fout:
    with open(CURRENT_NOTEBOOK_PATH, "rb") as fin:
        fout.write(fin.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-273-a0aa37ac42bf> in <module>
#       5 # Copy and compress current notebook
#       6 with bz2.open(SUBMISSION_NOTEBOOK_PATH, mode="wb") as fout:
# ----> 7     with open(CURRENT_NOTEBOOK_PATH, "rb") as fin:
#       8         fout.write(fin.read())
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/feliciasegui/Desktop/LP1 2020/Språkteknologi/4-chunker_solution.ipynb'

# %%
res = requests.post("https://vilde.cs.lth.se/edan20checker/submit", 
                    files={"notebook_file": open(SUBMISSION_NOTEBOOK_PATH, "rb")}, 
                    data={
                        "stil_id": STIL_ID,
                        "assignment": ASSIGNMENT,
                        "answer": ANSWER,
                        "api_key": API_KEY,
                    },
               verify=True)

# from IPython.display import display, JSON
res.json()
# Out:
# {'msg': None,
#  'status': 'correct',
#  'signature': '44d25dade9b27ca3958bb540a9c4162853e05c9858a8d72dedfcc3847fa253f493793ac464ec821aa9e51f2b3d36799d67ce93183182c1a0d001969f313f6682',
#  'submission_id': 'ba27ca6b-e185-4bd0-a357-47c2ed817e68'}

# %% [markdown]
# ## Reading

# %% [markdown]
# You will read the article, <a href="https://www.aclweb.org/anthology/C18-1139"><i>Contextual String
#             Embeddings for Sequence Labeling</i></a> by Akbik et al. (2018)
#             and you will outline the main differences between their system and yours. A LSTM is a type of
#             recurrent neural network, while CRF is a sort of beam search. You will tell the performance
#             they reach on the corpus you used in this laboratory.
